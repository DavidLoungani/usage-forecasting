# %%
import warnings
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

warnings.filterwarnings("ignore")

''' Database querying '''


def getDatabaseConnection():
    import os
    import yaml
    from sqlalchemy import create_engine
    db_conn = os.path.join(os.getcwd(), "db_connections/db_connections.yml")
    with open(db_conn, 'r') as ymlfile:
        db_conns = yaml.load(ymlfile)
    redshift = db_conns['Redshift']
    # megavolt = db_conns['Megavolt']
    engine = 'postgresql://{username}:{password}@{host}:{port}/{database}'.format(username=redshift['username'],
                                                                                  password=redshift['password'],
                                                                                  host=redshift['host'],
                                                                                  port=redshift['port'],
                                                                                  database=redshift['database'])
    conn = create_engine(engine, connect_args={'sslmode': 'require'})
    return conn


def queryDatabase():
    def queryInvoiceData(conn):
        p1 = "with cte as (select a.iethicalid, a.cesuniqueid, a.szip, it.* from ee.accounts a join ee.v_invoicestemp it on it.uniqueaccountid = a.cesuniqueid)"
        p2 = "select distinct iethicalid, szip, invoicefromdt, invoicetodt, kwh from cte order by iethicalid"
        q = p1 + p2
        df = pd.read_sql_query(q, con=conn)
        return df

    conn = getDatabaseConnection()
    invoice_dataframe = queryInvoiceData(conn)
    closest_stations_dataframe = pd.read_sql_query("select * from public.weather_stations where ord=1;", con=conn)
    weather_data = pd.read_sql_query("select wban, yearmonthday, tavg from consumption.noaa_data", con=conn)
    merged_invoice_df = pd.merge(invoice_dataframe, closest_stations_dataframe, left_on='szip', right_on='zip')
    merged_invoice_df['invoicefromdt'] = pd.to_datetime(merged_invoice_df['invoicefromdt'])
    merged_invoice_df['invoicetodt'] = pd.to_datetime(merged_invoice_df['invoicetodt'])
    cust_database = CustomerDatabase(merged_invoice_df, weather_data)
    return cust_database


''' Utility functions '''


def shaveData(dataframe, col, final_time):
    # Shave off time intervals after specified final time
    found = False
    final_time_idx = len(dataframe.index)
    for idx in dataframe.index:
        if (dataframe[col][idx] > final_time) and not found:
            final_time_idx = idx
            found = True
    return dataframe[0:final_time_idx]


def addTemporalValues(dataframe):
    # split timestamp into year, month, and day values, for regression
    dataframe['year'] = list(map(lambda x: x.year, dataframe['invoicetodt']))
    dataframe['month'] = list(map(lambda x: x.month, dataframe['invoicetodt']))
    dataframe['day'] = list(map(lambda x: x.day, dataframe['invoicetodt']))

    # Add a "days passed" column and iterate over dataframe to complete it'
    dataframe['days_passed'] = list(map(lambda x: (x - dataframe['invoicetodt'][0]).days, dataframe['invoicetodt']))

    return dataframe


def massage(data):
    # massage the data to make pandas happy
    length = len(data)
    data = np.asmatrix(data)
    data = data.reshape(length, 1)
    return data


def copyCustomer(customer):
    c = Customer(customer.id, customer.data.copy())
    c.createEval()
    return c


# TODO: Not sure if this actually works!!! Is there a better way to do this?
def createFactors(a, b):
    final = (a[a.columns[0]] * b[b.columns[0]]).as_matrix()
    final = final.reshape(len(final), 1)
    i = 0
    j = 1
    while i < len(a.columns):
        while j < len(b.columns):
            temp = (a[a.columns[i]] * b[b.columns[j]])
            temp = temp.reshape(len(temp), 1)
            final = np.hstack((final, temp))
            j += 1
        j = 0
        i += 1
    return final



''' Classes '''


def merge(slice_1, slice_2):
    slice_1.listSufficient.extend(slice_2.listSufficient)
    slice_1.listInsufficient.extend(slice_2.listInsufficient)
    merged_slice = CustomerSlice(slice_1.listSufficient, slice_1.listInsufficient)
    return merged_slice


class CustomerDatabase:
    def __init__(self, invoice_df, weather_df):
        self.invoice_df = invoice_df
        self.weather_df = weather_df

    def getSpecificCustomerDataframe(self, selected_id: str) -> pd.DataFrame:
        # Internal methods
        def calculatePeriod(fromdt, todt):
            return pd.period_range(fromdt, todt, freq='D')

        def cleanVals(x):
            if x is 'M':
                x = None
            else:
                x = pd.to_numeric(x, errors='coerce')
            return x

        customer_usage_df = ((self.invoice_df.loc[self.invoice_df['iethicalid'] == selected_id]).sort_values(
            by='invoicefromdt')).reset_index()
        # Shave off unnecessary values (unnecessary, for now!)
        customer_usage_df_final = customer_usage_df[['invoicetodt', 'kwh']].copy()
        # check to make sure weather station does not change
        if (customer_usage_df['wban'].nunique()) == 1:
            weather_station = int(customer_usage_df['wban'][0])
        else:
            raise ValueError('Customer changes weather stations')

        # Convert all values from strings to numerics, and change M's to NaNs
        weather_df_slice = self.weather_df[self.weather_df['wban'] == weather_station]
        weather_df_slice['tavg'] = list(map(cleanVals, weather_df_slice['tavg']))

        for interval_idx in customer_usage_df_final.index:
            days = calculatePeriod(customer_usage_df['invoicefromdt'][interval_idx],
                                   customer_usage_df['invoicetodt'][interval_idx])
            plotframe = pd.DataFrame(days, columns=['day'])

            def to_dateQuery(date):
                temp_string = str(date.year)
                if date.month < 10:
                    temp_string += "0"
                temp_string += str(date.month)

                if date.day < 10:
                    temp_string += "0"
                temp_string += str(date.day)
                return int(temp_string)

            plotframe['dateQuery'] = list(map(to_dateQuery, plotframe['day']))

            combined_usage_data = pd.merge(plotframe, weather_df_slice, left_on='dateQuery', right_on='yearmonthday')
            interval_temp_sum = np.sum(combined_usage_data['tavg'])

            # Last robustness check - otherwise set the tavg interval sum
            if interval_temp_sum == 0:
                customer_usage_df_final.loc[[interval_idx], 'tavg_intervalSum'] = None
            else:
                customer_usage_df_final.loc[[interval_idx], 'tavg_intervalSum'] = interval_temp_sum

        return customer_usage_df_final

    def getSpecificCustomer(self, selected_id):
        customer_usage_df = self.getSpecificCustomerDataframe(selected_id)

        # drop NA's
        if customer_usage_df.isnull().values.any():
            customer_usage_df = customer_usage_df.dropna()

        length = len(customer_usage_df)
        if length < 5:
            raise ValueError('insufficient data on customer: ID' + str(selected_id))

        customer = Customer(selected_id, customer_usage_df)
        return customer

    def selectSliceByIDs(self, id_list):
        print('Selecting slice by IDs...')
        num_processed_customers = 0
        num_discarded_customers = 0
        num_customers = len(id_list)

        list_sufficient = []
        list_insufficient = []

        for uniqueID in id_list:
            percent = ((num_processed_customers + num_discarded_customers) / num_customers) * 100
            print('Percent completed:  ' + str(percent) + '%')
            try:
                customer = self.getSpecificCustomer(uniqueID)
                customer.formatData()
                print('Customer selected: ' + str(uniqueID))
                list_sufficient.append(customer)
                num_processed_customers += 1
            except ValueError:
                print("Customer discarded, insufficient data: " + str(uniqueID))
                list_insufficient.append(uniqueID)
                num_discarded_customers += 1

        print('selectSliceByIDs terminated successfully')
        print('Processed customers: ' + str(num_processed_customers))
        print('Discarded customers: ' + str(num_discarded_customers))

        cust_slice = CustomerSlice(list_sufficient, list_insufficient)
        return cust_slice

    def selectAllCustomers(self):
        id_list = self.invoice_df['iethicalid'].unique()
        cust_slice = self.selectSliceByIDs(id_list)
        return cust_slice

    def selectRandomSlice(self, cust_count):
        from random import shuffle
        id_list = self.invoice_df['iethicalid'].unique().copy()

        if cust_count > len(id_list):
            raise ValueError('Cannot request more customers than exists in database')

        shuffle(id_list)
        id_list = id_list[0:cust_count]
        cust_slice = self.selectSliceByIDs(id_list)
        return cust_slice

    # TODO: Problem, this leaves the possibility of non-unique customers being merged
    def selectRandomHardSlice(self, cust_count):
        cust_slice = self.selectRandomSlice(cust_count)
        num_processed = len(cust_slice.listSufficient)
        while num_processed < cust_count:
            cust_slice = merge(cust_slice, self.selectRandomSlice(cust_count - num_processed))
            num_processed = len(cust_slice.listSufficient)
        return cust_slice


class CustomerSlice:
    def __init__(self, list_sufficient, list_insufficient):
        self.listSufficient = list_sufficient
        self.listInsufficient = list_insufficient
        self.iter = 0
        columns = ['regression approach', 'RMSQE', 'AE', 'MAE']
        self.grand_errorFrame = pd.DataFrame(columns=columns)

    def get_ID_list(self):
        id_list = []
        for customer in self.listSufficient:
            id_list.append(customer.id)
        return id_list

    def copy(self):
        new_slice = CustomerSlice(list(map(copyCustomer, self.listSufficient)), self.listInsufficient)
        return new_slice

    def reset_grand_errorFrame(self, algorithms):
        for idx in algorithms.index:
            self.grand_errorFrame.loc[idx] = ['predicted_kwh_' + str(algorithms['name'][idx]), 0, 0, 0]
        for idx in self.grand_errorFrame.index:
            self.grand_errorFrame.loc[[idx], 'AE'] = 0
            self.grand_errorFrame.loc[[idx], 'MAE'] = 0

    def runModels(self, train_columns, categorical_columns, target_column, algorithms):
        num_customers = len(self.listSufficient)
        count = 0
        self.reset_grand_errorFrame(algorithms)
        # TODO: VECTORIZE THE FOR LOOPS ?
        for customer in self.listSufficient:
            customer.runModels(train_columns, categorical_columns, target_column, algorithms)
            for idx in algorithms.index:
                self.grand_errorFrame.loc[[idx], 'AE'] += \
                    int(customer.errorFrame[customer.errorFrame['regression approach']
                                            == 'predicted_kwh_' + str(algorithms['name'][idx])]['AE'])
                self.grand_errorFrame.loc[[idx], 'MAE'] += \
                    int(customer.errorFrame[customer.errorFrame['regression approach']
                                            == 'predicted_kwh_' + str(algorithms['name'][idx])]['MAE'])
            count += 1
            percent = (count / num_customers) * 100
            print('Percent completed:  ' + str(percent) + '%')

        for idx in algorithms.index:
            self.grand_errorFrame.loc[[idx], 'MAE'] = self.grand_errorFrame['MAE'][idx] / len(self.listSufficient)

    def getSummaryStats(self, column):
        num_customers = len(self.listSufficient)
        count = 0

        # average
        sum = 0
        for customer in self.listSufficient:
            sum += customer.data[column].mean()
            count += 1
        avg = sum / count
        return avg

    def displayErrors(self):
        plt.figure(figsize=(8, 4))
        y_pos = np.arange(len(self.grand_errorFrame['regression approach']))
        plt.bar(y_pos, self.grand_errorFrame['AE'])
        plt.xticks(y_pos, self.grand_errorFrame['regression approach'])
        plt.legend(loc='best')
        plt.title('Aggregate errors in slice')
        plt.show()

    def resetIter(self):
        self.iter = 0

    def iterNext(self):
        if self.iter + 1 < len(self.listSufficient):
            self.iter += 1
        else:
            print('Resetting iter, reached end of list')
            self.resetIter()

    def displayAndNext(self, algorithms):
        self.listSufficient[self.iter].displayConclusions(algorithms)
        self.iterNext()

    def classificationTest(self):
        df = pd.DataFrame(columns=['customer', 'id', 'class'])
        df['customer'] = self.listSufficient
        for idx in df.index:
            df['id'][idx] = df['customer'][idx].id
            t_at_high = df['customer'][idx].getValueAtMax('kwh', 'tavg_intervalSum')
            t_at_low = df['customer'][idx].getValueAtMin('kwh', 'tavg_intervalSum')
            if t_at_high > t_at_low:
                df['class'][idx] = "summer peaker"
            elif t_at_high < t_at_low:
                df['class'][idx] = "winter peaker"
            else:
                df['class'][idx] = "pattern unclear"
        return df

    def createAggregateFrame(self):
        count = 1
        aggFrame = self.listSufficient[0].non_eval
        while (count < len(self.listSufficient)):
            aggFrame = aggFrame.append(self.listSufficient[count].non_eval)
            count = count + 1
        self.aggFrame = aggFrame.sort_values(by='invoicetodt').reset_index().drop('index', 1)

    def createTestFrame(self, algorithms):
        count = 1
        testFrame = self.listSufficient[0].eval
        while (count < len(self.listSufficient)):
            testFrame = testFrame.append(self.listSufficient[count].eval)
            count = count + 1
        self.allFrame = pd.concat([self.aggFrame, testFrame])
        self.testFrame = testFrame.reset_index()
        for idx in algorithms.index:
            self.testFrame['predicted_kwh_' + str(algorithms['name'][idx])] = None

    def create_aggregate_ErrorFrame(self, algorithms):
        columns = ['regression approach', 'RMSQE', 'AE', 'MAE']
        self.agg_errorFrame = pd.DataFrame(columns=columns)
        for idx in algorithms.index:
            self.agg_errorFrame.loc[idx] = ['predicted_kwh_' + str(algorithms['name'][idx]), 0, 0, 0]

    def createTrainSets(self, train_columns, categorical_columns, interaction_columns, target_column):
        train_X = self.aggFrame.as_matrix(columns=train_columns)
        # TODO: Vectorize and Abstract? Right now categorical/interactions are a mess...
        for column in categorical_columns:
            cat_col = pd.Categorical(self.aggFrame[column])
            mx_dummies = pd.get_dummies(cat_col)
            train_X = np.hstack((train_X, mx_dummies))
        # TODO: The interaction variable creation here is disgustingly messy
        for entry in interaction_columns:
            if (entry[2]=='categorical'):
                cat_col = pd.Categorical(self.aggFrame[entry[0]])
                mx_dummies = pd.get_dummies(cat_col)
                a = mx_dummies
            else:
                mx = self.aggFrame.as_matrix(columns=[entry[0]])
                a = pd.DataFrame(mx, columns=['numerical'])
            if (entry[3]=='categorical'):
                cat_col = pd.Categorical(self.aggFrame[entry[1]])
                mx_dummies = pd.get_dummies(cat_col)
                b = mx_dummies
            else:
                mx = self.aggFrame.as_matrix(columns=[entry[1]])
                b = pd.DataFrame(mx, columns=['numerical'])
            interaction_data = createFactors(a, b)
            train_X = np.hstack((train_X, interaction_data))
        train_y = self.aggFrame.as_matrix(columns=[target_column])
        return train_X, train_y

    def createTestSets(self, train_columns, categorical_columns, interaction_columns, target_column):
        test_X = self.testFrame.as_matrix(columns=train_columns)
        # TODO: Vectorize
        for column in categorical_columns:
            cat_col = pd.Categorical(self.testFrame[column])
            mx_dummies = pd.get_dummies(cat_col)
            test_X = np.hstack((test_X, mx_dummies))
        # TODO: The interaction variable creation here is disgustingly messy
        for entry in interaction_columns:
            if (entry[2] == 'categorical'):
                cat_col = pd.Categorical(self.testFrame[entry[0]])
                mx_dummies = pd.get_dummies(cat_col)
                a = mx_dummies
            else:
                mx = self.testFrame.as_matrix(columns=[entry[0]])
                a = pd.DataFrame(mx, columns=['numerical'])
            if (entry[3] == 'categorical'):
                cat_col = pd.Categorical(self.testFrame[entry[1]])
                mx_dummies = pd.get_dummies(cat_col)
                b = mx_dummies
            else:
                mx = self.testFrame.as_matrix(columns=[entry[1]])
                b = pd.DataFrame(mx, columns=['numerical'])
            interaction_data = createFactors(a, b)
            test_X = np.hstack((test_X, interaction_data))
        test_y = self.testFrame.as_matrix(columns=[target_column])
        return test_X, test_y

    def run_aggregate_models(self, train_columns, categorical_columns, interaction_columns, target_column, algorithms):
        self.createAggregateFrame()
        self.createTestFrame(algorithms)
        self.create_aggregate_ErrorFrame(algorithms)

        train_X, train_y = self.createTrainSets(train_columns, categorical_columns, interaction_columns, target_column)
        target_X, target_y = self.createTestSets(train_columns, categorical_columns, interaction_columns, target_column)

        algorithms['fitted_model'] = algorithms['algorithm']
        # TODO: Vectorize
        for idx in algorithms.index:
            current_algo =  algorithms['algorithm'][idx]
            algorithms['fitted_model'][idx] = current_algo.fit(train_X, train_y)
            for cust_idx in self.testFrame.index:
                self.testFrame['predicted_kwh_' + str(algorithms['name'][idx])][cust_idx] = int(current_algo.predict(target_X[cust_idx]))
                self.agg_errorFrame.loc[[idx], 'AE'] += int(abs(target_y[cust_idx] - int(current_algo.predict(target_X[cust_idx]))))
            self.agg_errorFrame.loc[[idx], 'MAE'] = self.agg_errorFrame['AE'][idx] / len(self.testFrame)


class Customer:
    def __init__(self, id, data):
        self.id = id
        self.data = data
        columns = ['regression approach', 'RMSQE', 'AE', 'MAE']
        self.errorFrame = pd.DataFrame(columns=columns)
        self.init_trainsize = int(len(self.data) * .8)

    def formatData(self):
        # sort by invoicetodt to make sure there is proper temporal ordering
        self.data = self.data.sort_values(by='invoicetodt')

        # add avg_kwh column
        self.data['avg_kwh'] = self.data['kwh'].sum() / len(self.data)

        # Shave off time intervals after February 25th, 2017
        # We do not currently have temperature data after this point
        col = 'invoicetodt'
        self.data = shaveData(self.data, col, pd.Timestamp(datetime(2017, 2, 25)))
        self.data = self.data.reset_index(drop=True)

        try:
            # add temporal information for models to use
            self.data = addTemporalValues(self.data)
        except KeyError:
            print("in formatting data, could not add temporal information to customer ID: " + str(self.id))
            raise ValueError("Temporal information formatting exception")

        try:
            # add one-period time lag
            self.data['prev_pd_kwh'] = list(map(lambda idx: self.data['kwh'][max(idx - 1, 0)], self.data.index))
            # add two-period time lag
            self.data['prev_prev_pd_kwh'] = list(map(lambda idx: self.data['kwh'][max(idx - 2, 0)], self.data.index))
            # Shave off first two values, because of the time lag
            self.data = self.data[2:]
        except KeyError:
            print("in formatting data, could not add time lags to customer ID: " + str(self.id))
            raise ValueError("Time lag formatting exception")

        # add to data which contains customer ID for each instance
        self.data['iethicalid'] = self.id
        self.createEval()

    def createEval(self):
        # Separate last row from rest of data - this will be used for prediction evaluation
        self.eval = self.data[len(self.data) - 1:]
        self.non_eval = self.data[0: len(self.data) - 1]



    def displayTempVsUsagePlots(self):
        plt.figure(figsize=(10, 4))
        plt.plot(self.data['invoicetodt'], self.data['kwh'], 'ro')
        plt.plot(self.data['invoicetodt'], self.data['tavg_intervalSum'], 'ro', color='green', )
        plt.title('Temperature and kWH values over time')
        plt.show()

        plt.figure(figsize=(10, 4))
        plt.plot(self.data['invoicetodt'], self.data['kwh'])
        plt.plot(self.data['invoicetodt'], self.data['tavg_intervalSum'], color='green', )
        plt.title('Temperature and kWH values over time')
        plt.show()

    def getTrainingSet(self, init_trainsize, date_idx, train_columns, categorical_columns, target_column):
        X = self.data.as_matrix(columns=train_columns)
        # TODO: Vectorize
        for column in categorical_columns:
            cat_col = pd.Categorical(self.data[column])
            mx_dummies = pd.get_dummies(cat_col)
            X = np.hstack((X, mx_dummies))
        y = self.data.as_matrix(columns=[target_column])
        train_X = X[: init_trainsize + date_idx]
        train_y = y[0: init_trainsize + date_idx]
        return train_X, train_y

    def getTestSet(self, init_trainsize, date_idx, train_columns, categorical_columns):
        X = self.data.as_matrix(columns=train_columns)
        # TODO: Vectorize
        for column in categorical_columns:
            cat_col = pd.Categorical(self.data[column])
            mx_dummies = pd.get_dummies(cat_col)
            X = np.hstack((X, mx_dummies))
        oos_X = X[init_trainsize+date_idx]
        return oos_X

    def setInitialVals(self, algorithms):
        self.data = self.data.reset_index()
        all_dates = self.data['invoicetodt']
        # Manually resetting the init_trainsize because it messes up for an unknown reason...
        self.init_trainsize = int(len(self.data) * .8)
        self.init_oos_dates = all_dates[self.init_trainsize:, ]
        self.init_oos_dates = self.init_oos_dates.reset_index()

        # TODO: Vectorize!??
        for idx in algorithms.index:
            self.data['predicted_kwh_' + str(algorithms['name'][idx])] = None
            self.errorFrame.loc[idx] = ['predicted_kwh_' + str(algorithms['name'][idx]), 0, 0, 0]

    def forecastOn(self, date_idx, train_columns, categorical_columns, target_column, algorithms):
        train_X, train_y = self.getTrainingSet(self.init_trainsize, date_idx, train_columns, categorical_columns, target_column)
        target_X = self.getTestSet(self.init_trainsize, date_idx, train_columns, categorical_columns)
        target_y = self.data['kwh'][self.init_trainsize + date_idx]


        algorithms['fitted_model'] = algorithms['algorithm']
        # TODO: Vectorize
        for idx in algorithms.index:
            algorithms['fitted_model'][idx] = algorithms['algorithm'][idx].fit(train_X, train_y)
            predicted_y = int(algorithms['fitted_model'][idx].predict(target_X))
            self.data['predicted_kwh_' + str(algorithms['name'][idx])][self.init_trainsize + date_idx] = predicted_y
            error = int(abs(target_y - predicted_y))
            self.errorFrame.loc[[idx], 'AE'] += error

    def runModels(self, train_columns, categorical_columns, target_column, algorithms):
        self.setInitialVals(algorithms)
        # TODO: Vectorize!
        for date_idx in self.init_oos_dates.index:
            self.forecastOn(date_idx, train_columns, categorical_columns, target_column, algorithms)
        for idx in algorithms.index:
            try:
                self.errorFrame.loc[[idx], 'MAE'] = self.errorFrame['AE'][idx] / len(self.init_oos_dates)
            except ZeroDivisionError:
                print('self.init_oos_dates: ')
                print(self.init_oos_dates)
                raise ValueError("ZeroDivisionError caught while running " + algorithms['name'][idx] + 'on customer: ' + str(self.id))
        self.errorFrame = self.errorFrame.sort_values(by='AE')
        self.errorFrame = self.errorFrame.reset_index(drop=True)

    def displayBestFit(self):
        plt.figure(figsize=(15, 4))
        plt.plot(self.data['invoicetodt'], self.data['kwh'], label='actual usage')
        plt.plot(self.data['invoicetodt'],
                 self.data[(self.errorFrame['regression approach'][0])],
                 color='green',
                 label=(self.errorFrame['regression approach'][0]))
        plt.legend(loc='best')
        plt.title('Customer ' + str(self.id) + ': Best fit')
        plt.show()

    def displayWorstFit(self):
        plt.figure(figsize=(15, 4))
        plt.plot(self.data['invoicetodt'], self.data['kwh'], label='actual usage')
        plt.plot(self.data['invoicetodt'],
                 self.data[(self.errorFrame['regression approach'][len(self.errorFrame) - 1])],
                 color='red', label=(self.errorFrame['regression approach'][len(self.errorFrame) - 1]))
        plt.legend(loc='best')
        plt.title('Customer ' + str(self.id) + ': Worst fit')
        plt.show()

    def displayConclusions(self, algorithms):
        # Plot the algorithm results
        plt.figure(figsize=(15, 4))
        plt.plot(self.data['invoicetodt'], self.data['kwh'], label='actual usage')
        plt.plot(self.data['invoicetodt'], self.data['tavg_intervalSum'], color='green',
                 label='temperature')
        # TODO: Assign a color for each algorithm!!!! AND VECTORIZE!
        for idx in algorithms.index:
            plt.plot(self.data['invoicetodt'],
                     self.data['predicted_kwh_' + str(algorithms['name'][idx])],
                     color='red',
                     label='predicted usage ' + str(algorithms['name'][idx]))
        plt.legend(loc='best')
        plt.title('Customer ' + str(self.id) + ': Temperature, kWH, and fitted values over entire time period')
        plt.show()

        self.displayBestFit()
        self.displayWorstFit()

    def displaySpecificAlgorithm(self, specified_algorithm_string):
        # Plot the algorithm results
        plt.figure(figsize=(15, 4))
        plt.plot(self.data['invoicetodt'], self.data['kwh'], label='actual usage')
        plt.plot(self.data['invoicetodt'], self.data['tavg_intervalSum'], color='green',
                 label='temperature')
        plt.plot(self.data['invoicetodt'], self.data['predicted_kwh_' + specified_algorithm_string], color='black',
                 alpha=0.9, label='predicted usage rf')
        plt.legend(loc='best')
        plt.title('Customer ' + str(self.id) + ': Temperature, kWH, and fitted values over entire time period')
        plt.show()

    def getMaximum(self, column):
        return self.data[column].max()

    def getMinimum(self, column):
        return self.data[column].min()

    def getValueAtMax(self, column_max, column_target):
        d = self.data.sort_values(by=column_max, ascending=False)
        return d.reset_index()[column_target][0]

    def getValueAtMin(self, column_min, column_target):
        d = self.data.sort_values(by=column_min, ascending=True)
        return d.reset_index()[column_target][0]


class TempComparisonTest:
    def __init__(self, cust_count):
        self.iter = 0
        print('Querying database...')
        self.cust_database = queryDatabase()
        self.cust_slice = self.cust_database.selectRandomHardSlice(cust_count)
        self.cust_slice_minus_temp = self.cust_slice.copy()

        my_algorithms_table = pd.DataFrame(columns=['name', 'algorithm'])
        my_algorithms_table['name'] = ['rf']
        my_algorithms_table['algorithm'] = [RandomForestRegressor(n_estimators=150, min_samples_split=2)]
        my_train_columns = ['tavg_intervalSum', 'prev_pd_kwh', 'prev_prev_pd_kwh', 'days_passed']
        my_categorical_columns = ['month']
        my_interaction_columns = [('month', 'iethicalid', 'categorical', 'categorical')]

        self.cust_slice.runModels(my_train_columns, my_categorical_columns, 'kwh', my_algorithms_table)

        my_train_columns_minus_temp = ['prev_pd_kwh', 'prev_prev_pd_kwh', 'days_passed']
        self.cust_slice_minus_temp.runModels(my_train_columns_minus_temp, my_categorical_columns, 'kwh', my_algorithms_table)

    def error_frames(self):
        print('RF MAE with Temp: ' + str(self.cust_slice.grand_errorFrame['MAE'][0]))
        print('RF MAE without temp: ' + str(self.cust_slice_minus_temp.grand_errorFrame['MAE'][0]))

    def avg_kwh(self):
        print('Average kwh used: ' + str(self.cust_slice.getSummaryStats('kwh')))

    def resetIter(self):
        self.iter = 0

    def iterNext(self):
        if self.iter + 1 < len(self.cust_slice.listSufficient):
            self.iter += 1
        else:
            print('Resetting iter, reached end of list')
            self.resetIter()

    def compareAndNext(self):
        self.cust_slice.listSufficient[self.iter].displaySpecificAlgorithm('rf')
        self.cust_slice_minus_temp.listSufficient[self.iter].displaySpecificAlgorithm('rf')
        self.iterNext()

# %%
cust_database = queryDatabase()

# %%
cust_slice = cust_database.selectRandomHardSlice(500)
# Out:
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer selected: 174319
# Percent completed:  0.2%
# Customer discarded, insufficient data: 188360
# Percent completed:  0.4%
# Customer discarded, insufficient data: 179282
# Percent completed:  0.6%
# Customer selected: 79957
# Percent completed:  0.8%
# Customer selected: 193580
# Percent completed:  1.0%
# Customer discarded, insufficient data: 99061
# Percent completed:  1.2%
# Customer discarded, insufficient data: 250900
# Percent completed:  1.4000000000000001%
# Customer selected: 171781
# Percent completed:  1.6%
# Customer selected: 67678
# Percent completed:  1.7999999999999998%
# Customer discarded, insufficient data: 247784
# Percent completed:  2.0%
# Customer discarded, insufficient data: 94894
# Percent completed:  2.1999999999999997%
# Customer selected: 196708
# Percent completed:  2.4%
# Customer selected: 133692
# Percent completed:  2.6%
# Customer selected: 162473
# Percent completed:  2.8000000000000003%
# Customer discarded, insufficient data: 97069
# Percent completed:  3.0%
# Customer selected: 12126
# Percent completed:  3.2%
# Customer discarded, insufficient data: 136750
# Percent completed:  3.4000000000000004%
# Customer discarded, insufficient data: 135761
# Percent completed:  3.5999999999999996%
# Customer selected: 62116
# Percent completed:  3.8%
# Customer discarded, insufficient data: 150717
# Percent completed:  4.0%
# Customer discarded, insufficient data: 118227
# Percent completed:  4.2%
# Customer discarded, insufficient data: 244556
# Percent completed:  4.3999999999999995%
# Customer discarded, insufficient data: 158876
# Percent completed:  4.6%
# Customer selected: 144602
# Percent completed:  4.8%
# Customer discarded, insufficient data: 72823
# Percent completed:  5.0%
# Customer discarded, insufficient data: 235843
# Percent completed:  5.2%
# Customer selected: 231931
# Percent completed:  5.4%
# Customer selected: 67904
# Percent completed:  5.6000000000000005%
# Customer discarded, insufficient data: 180900
# Percent completed:  5.800000000000001%
# Customer discarded, insufficient data: 273926
# Percent completed:  6.0%
# Customer discarded, insufficient data: 92768
# Percent completed:  6.2%
# Customer discarded, insufficient data: 256057
# Percent completed:  6.4%
# Customer discarded, insufficient data: 139540
# Percent completed:  6.6000000000000005%
# Customer discarded, insufficient data: 263898
# Percent completed:  6.800000000000001%
# Customer discarded, insufficient data: 67543
# Percent completed:  7.000000000000001%
# Customer discarded, insufficient data: 248096
# Percent completed:  7.199999999999999%
# Customer selected: 192009
# Percent completed:  7.3999999999999995%
# Customer selected: 60930
# Percent completed:  7.6%
# Customer selected: 146109
# Percent completed:  7.8%
# Customer selected: 82546
# Percent completed:  8.0%
# Customer discarded, insufficient data: 230161
# Percent completed:  8.200000000000001%
# Customer selected: 147259
# Percent completed:  8.4%
# Customer discarded, insufficient data: 58360
# Percent completed:  8.6%
# Customer selected: 210348
# Percent completed:  8.799999999999999%
# Customer selected: 29267
# Percent completed:  9.0%
# Customer selected: 99649
# Percent completed:  9.2%
# Customer selected: 196296
# Percent completed:  9.4%
# Customer discarded, insufficient data: 250108
# Percent completed:  9.6%
# Customer discarded, insufficient data: 269724
# Percent completed:  9.8%
# Customer discarded, insufficient data: 276624
# Percent completed:  10.0%
# Customer discarded, insufficient data: 221878
# Percent completed:  10.2%
# Customer discarded, insufficient data: 130696
# Percent completed:  10.4%
# Customer discarded, insufficient data: 200482
# Percent completed:  10.6%
# Customer selected: 6480
# Percent completed:  10.8%
# Customer selected: 212536
# Percent completed:  11.0%
# Customer selected: 79396
# Percent completed:  11.200000000000001%
# Customer discarded, insufficient data: 233344
# Percent completed:  11.4%
# Customer discarded, insufficient data: 184726
# Percent completed:  11.600000000000001%
# Customer discarded, insufficient data: 262553
# Percent completed:  11.799999999999999%
# Customer selected: 142789
# Percent completed:  12.0%
# Customer discarded, insufficient data: 94937
# Percent completed:  12.2%
# Customer discarded, insufficient data: 245770
# Percent completed:  12.4%
# Customer selected: 205406
# Percent completed:  12.6%
# Customer discarded, insufficient data: 31107
# Percent completed:  12.8%
# Customer selected: 224809
# Percent completed:  13.0%
# Customer discarded, insufficient data: 256094
# Percent completed:  13.200000000000001%
# Customer selected: 139729
# Percent completed:  13.4%
# Customer selected: 226420
# Percent completed:  13.600000000000001%
# Customer selected: 220664
# Percent completed:  13.8%
# Customer selected: 55148
# Percent completed:  14.000000000000002%
# Customer discarded, insufficient data: 249638
# Percent completed:  14.2%
# Customer discarded, insufficient data: 149167
# Percent completed:  14.399999999999999%
# Customer selected: 178620
# Percent completed:  14.6%
# Customer discarded, insufficient data: 79440
# Percent completed:  14.799999999999999%
# Customer selected: 18328
# Percent completed:  15.0%
# Customer discarded, insufficient data: 106895
# Percent completed:  15.2%
# Customer discarded, insufficient data: 239511
# Percent completed:  15.4%
# Customer selected: 12125
# Percent completed:  15.6%
# Customer discarded, insufficient data: 262287
# Percent completed:  15.8%
# Customer discarded, insufficient data: 247111
# Percent completed:  16.0%
# Customer selected: 115045
# Percent completed:  16.2%
# Customer discarded, insufficient data: 87676
# Percent completed:  16.400000000000002%
# Customer selected: 63269
# Percent completed:  16.6%
# Customer selected: 124146
# Percent completed:  16.8%
# Customer discarded, insufficient data: 16952
# Percent completed:  17.0%
# Customer discarded, insufficient data: 242423
# Percent completed:  17.2%
# Customer selected: 82181
# Percent completed:  17.4%
# Customer selected: 117622
# Percent completed:  17.599999999999998%
# Customer discarded, insufficient data: 267403
# Percent completed:  17.8%
# Customer discarded, insufficient data: 26693
# Percent completed:  18.0%
# Customer selected: 83381
# Percent completed:  18.2%
# Customer discarded, insufficient data: 88303
# Percent completed:  18.4%
# Customer discarded, insufficient data: 219909
# Percent completed:  18.6%
# Customer selected: 98942
# Percent completed:  18.8%
# Customer discarded, insufficient data: 246467
# Percent completed:  19.0%
# Customer selected: 30587
# Percent completed:  19.2%
# Customer selected: 101418
# Percent completed:  19.400000000000002%
# Customer selected: 147638
# Percent completed:  19.6%
# Customer discarded, insufficient data: 245399
# Percent completed:  19.8%
# Customer discarded, insufficient data: 268154
# Percent completed:  20.0%
# Customer discarded, insufficient data: 116588
# Percent completed:  20.200000000000003%
# Customer selected: 89676
# Percent completed:  20.4%
# Customer discarded, insufficient data: 271879
# Percent completed:  20.599999999999998%
# Customer selected: 92393
# Percent completed:  20.8%
# Customer selected: 182852
# Percent completed:  21.0%
# Customer selected: 122539
# Percent completed:  21.2%
# Customer discarded, insufficient data: 250276
# Percent completed:  21.4%
# Customer selected: 226107
# Percent completed:  21.6%
# Customer selected: 230388
# Percent completed:  21.8%
# Customer discarded, insufficient data: 56007
# Percent completed:  22.0%
# Customer discarded, insufficient data: 14753
# Percent completed:  22.2%
# Customer selected: 122797
# Percent completed:  22.400000000000002%
# Customer discarded, insufficient data: 271818
# Percent completed:  22.6%
# Customer discarded, insufficient data: 62609
# Percent completed:  22.8%
# Customer selected: 12792
# Percent completed:  23.0%
# Customer discarded, insufficient data: 173804
# Percent completed:  23.200000000000003%
# Customer selected: 52583
# Percent completed:  23.400000000000002%
# Customer discarded, insufficient data: 249903
# Percent completed:  23.599999999999998%
# Customer selected: 134287
# Percent completed:  23.799999999999997%
# Customer selected: 195395
# Percent completed:  24.0%
# Customer discarded, insufficient data: 267430
# Percent completed:  24.2%
# Customer selected: 177276
# Percent completed:  24.4%
# Customer discarded, insufficient data: 221264
# Percent completed:  24.6%
# Customer selected: 175482
# Percent completed:  24.8%
# Customer discarded, insufficient data: 17701
# Percent completed:  25.0%
# Customer selected: 14962
# Percent completed:  25.2%
# Customer discarded, insufficient data: 92529
# Percent completed:  25.4%
# Customer selected: 231183
# Percent completed:  25.6%
# Customer selected: 32396
# Percent completed:  25.8%
# Customer selected: 44227
# Percent completed:  26.0%
# Customer discarded, insufficient data: 138762
# Percent completed:  26.200000000000003%
# Customer discarded, insufficient data: 120210
# Percent completed:  26.400000000000002%
# Customer discarded, insufficient data: 114117
# Percent completed:  26.6%
# Customer selected: 42572
# Percent completed:  26.8%
# Customer discarded, insufficient data: 273775
# Percent completed:  27.0%
# Customer discarded, insufficient data: 232335
# Percent completed:  27.200000000000003%
# Customer discarded, insufficient data: 71751
# Percent completed:  27.400000000000002%
# Customer discarded, insufficient data: 273647
# Percent completed:  27.6%
# Customer selected: 67093
# Percent completed:  27.800000000000004%
# Customer discarded, insufficient data: 179248
# Percent completed:  28.000000000000004%
# Customer selected: 142695
# Percent completed:  28.199999999999996%
# Customer discarded, insufficient data: 66549
# Percent completed:  28.4%
# Customer discarded, insufficient data: 208666
# Percent completed:  28.599999999999998%
# Customer discarded, insufficient data: 103965
# Percent completed:  28.799999999999997%
# Customer selected: 162636
# Percent completed:  28.999999999999996%
# Customer discarded, insufficient data: 112432
# Percent completed:  29.2%
# Customer selected: 158208
# Percent completed:  29.4%
# Customer discarded, insufficient data: 250996
# Percent completed:  29.599999999999998%
# Customer selected: 174209
# Percent completed:  29.799999999999997%
# Customer selected: 32351
# Percent completed:  30.0%
# Customer discarded, insufficient data: 142113
# Percent completed:  30.2%
# Customer selected: 92416
# Percent completed:  30.4%
# Customer discarded, insufficient data: 241333
# Percent completed:  30.599999999999998%
# Customer selected: 62672
# Percent completed:  30.8%
# Customer discarded, insufficient data: 1719
# Percent completed:  31.0%
# Customer selected: 171017
# Percent completed:  31.2%
# Customer selected: 211432
# Percent completed:  31.4%
# Customer discarded, insufficient data: 55613
# Percent completed:  31.6%
# Customer selected: 132618
# Percent completed:  31.8%
# Customer selected: 189306
# Percent completed:  32.0%
# Customer discarded, insufficient data: 144665
# Percent completed:  32.2%
# Customer discarded, insufficient data: 213032
# Percent completed:  32.4%
# Customer discarded, insufficient data: 96817
# Percent completed:  32.6%
# Customer selected: 170925
# Percent completed:  32.800000000000004%
# Customer selected: 67915
# Percent completed:  33.0%
# Customer selected: 43688
# Percent completed:  33.2%
# Customer selected: 166031
# Percent completed:  33.4%
# Customer selected: 139934
# Percent completed:  33.6%
# Customer discarded, insufficient data: 234232
# Percent completed:  33.800000000000004%
# Customer selected: 150259
# Percent completed:  34.0%
# Customer selected: 83680
# Percent completed:  34.2%
# Customer selected: 31867
# Percent completed:  34.4%
# Customer selected: 52452
# Percent completed:  34.599999999999994%
# Customer discarded, insufficient data: 39198
# Percent completed:  34.8%
# Customer discarded, insufficient data: 265428
# Percent completed:  35.0%
# Customer selected: 155494
# Percent completed:  35.199999999999996%
# Customer selected: 116514
# Percent completed:  35.4%
# Customer selected: 214625
# Percent completed:  35.6%
# Customer selected: 9063
# Percent completed:  35.8%
# Customer selected: 206797
# Percent completed:  36.0%
# Customer discarded, insufficient data: 31534
# Percent completed:  36.199999999999996%
# Customer selected: 112687
# Percent completed:  36.4%
# Customer discarded, insufficient data: 168769
# Percent completed:  36.6%
# Customer discarded, insufficient data: 57252
# Percent completed:  36.8%
# Customer selected: 226582
# Percent completed:  37.0%
# Customer selected: 77002
# Percent completed:  37.2%
# Customer selected: 93520
# Percent completed:  37.4%
# Customer selected: 202850
# Percent completed:  37.6%
# Customer discarded, insufficient data: 274941
# Percent completed:  37.8%
# Customer discarded, insufficient data: 91744
# Percent completed:  38.0%
# Customer discarded, insufficient data: 47170
# Percent completed:  38.2%
# Customer discarded, insufficient data: 130853
# Percent completed:  38.4%
# Customer discarded, insufficient data: 193058
# Percent completed:  38.6%
# Customer discarded, insufficient data: 264445
# Percent completed:  38.800000000000004%
# Customer selected: 231255
# Percent completed:  39.0%
# Customer discarded, insufficient data: 219826
# Percent completed:  39.2%
# Customer selected: 173709
# Percent completed:  39.4%
# Customer selected: 179982
# Percent completed:  39.6%
# Customer discarded, insufficient data: 41242
# Percent completed:  39.800000000000004%
# Customer selected: 142612
# Percent completed:  40.0%
# Customer discarded, insufficient data: 236536
# Percent completed:  40.2%
# Customer discarded, insufficient data: 251402
# Percent completed:  40.400000000000006%
# Customer discarded, insufficient data: 2988
# Percent completed:  40.6%
# Customer discarded, insufficient data: 147230
# Percent completed:  40.8%
# Customer discarded, insufficient data: 248486
# Percent completed:  41.0%
# Customer discarded, insufficient data: 139374
# Percent completed:  41.199999999999996%
# Customer selected: 154490
# Percent completed:  41.4%
# Customer discarded, insufficient data: 259389
# Percent completed:  41.6%
# Customer discarded, insufficient data: 280207
# Percent completed:  41.8%
# Customer discarded, insufficient data: 171496
# Percent completed:  42.0%
# Customer selected: 169018
# Percent completed:  42.199999999999996%
# Customer discarded, insufficient data: 32888
# Percent completed:  42.4%
# Customer discarded, insufficient data: 157893
# Percent completed:  42.6%
# Customer discarded, insufficient data: 195809
# Percent completed:  42.8%
# Customer discarded, insufficient data: 126481
# Percent completed:  43.0%
# Customer discarded, insufficient data: 269491
# Percent completed:  43.2%
# Customer discarded, insufficient data: 86598
# Percent completed:  43.4%
# Customer selected: 211961
# Percent completed:  43.6%
# Customer discarded, insufficient data: 135264
# Percent completed:  43.8%
# Customer selected: 203029
# Percent completed:  44.0%
# Customer discarded, insufficient data: 197649
# Percent completed:  44.2%
# Customer selected: 139394
# Percent completed:  44.4%
# Customer discarded, insufficient data: 34422
# Percent completed:  44.6%
# Customer discarded, insufficient data: 181359
# Percent completed:  44.800000000000004%
# Customer discarded, insufficient data: 120934
# Percent completed:  45.0%
# Customer selected: 75576
# Percent completed:  45.2%
# Customer discarded, insufficient data: 270886
# Percent completed:  45.4%
# Customer discarded, insufficient data: 253639
# Percent completed:  45.6%
# Customer discarded, insufficient data: 137859
# Percent completed:  45.800000000000004%
# Customer discarded, insufficient data: 66694
# Percent completed:  46.0%
# Customer selected: 88797
# Percent completed:  46.2%
# Customer discarded, insufficient data: 100262
# Percent completed:  46.400000000000006%
# Customer discarded, insufficient data: 251521
# Percent completed:  46.6%
# Customer discarded, insufficient data: 109723
# Percent completed:  46.800000000000004%
# Customer selected: 11313
# Percent completed:  47.0%
# Customer discarded, insufficient data: 96029
# Percent completed:  47.199999999999996%
# Customer discarded, insufficient data: 240046
# Percent completed:  47.4%
# Customer discarded, insufficient data: 131252
# Percent completed:  47.599999999999994%
# Customer selected: 139983
# Percent completed:  47.8%
# Customer discarded, insufficient data: 107496
# Percent completed:  48.0%
# Customer selected: 26492
# Percent completed:  48.199999999999996%
# Customer discarded, insufficient data: 173622
# Percent completed:  48.4%
# Customer selected: 156875
# Percent completed:  48.6%
# Customer discarded, insufficient data: 201121
# Percent completed:  48.8%
# Customer selected: 199841
# Percent completed:  49.0%
# Customer selected: 9148
# Percent completed:  49.2%
# Customer discarded, insufficient data: 196834
# Percent completed:  49.4%
# Customer discarded, insufficient data: 232981
# Percent completed:  49.6%
# Customer discarded, insufficient data: 152220
# Percent completed:  49.8%
# Customer discarded, insufficient data: 155635
# Percent completed:  50.0%
# Customer discarded, insufficient data: 103287
# Percent completed:  50.2%
# Customer discarded, insufficient data: 131465
# Percent completed:  50.4%
# Customer selected: 109506
# Percent completed:  50.6%
# Customer discarded, insufficient data: 131903
# Percent completed:  50.8%
# Customer discarded, insufficient data: 154761
# Percent completed:  51.0%
# Customer selected: 6013
# Percent completed:  51.2%
# Customer discarded, insufficient data: 257423
# Percent completed:  51.4%
# Customer selected: 127592
# Percent completed:  51.6%
# Customer discarded, insufficient data: 68448
# Percent completed:  51.800000000000004%
# Customer selected: 95002
# Percent completed:  52.0%
# Customer discarded, insufficient data: 242291
# Percent completed:  52.2%
# Customer selected: 213766
# Percent completed:  52.400000000000006%
# Customer selected: 12271
# Percent completed:  52.6%
# Customer discarded, insufficient data: 72187
# Percent completed:  52.800000000000004%
# Customer selected: 30556
# Percent completed:  53.0%
# Customer discarded, insufficient data: 214474
# Percent completed:  53.2%
# Customer discarded, insufficient data: 252840
# Percent completed:  53.400000000000006%
# Customer selected: 145499
# Percent completed:  53.6%
# Customer selected: 32016
# Percent completed:  53.800000000000004%
# Customer selected: 139829
# Percent completed:  54.0%
# Customer selected: 5650
# Percent completed:  54.2%
# Customer selected: 224752
# Percent completed:  54.400000000000006%
# Customer selected: 154525
# Percent completed:  54.6%
# Customer discarded, insufficient data: 241608
# Percent completed:  54.800000000000004%
# Customer selected: 115491
# Percent completed:  55.00000000000001%
# Customer discarded, insufficient data: 243953
# Percent completed:  55.2%
# Customer selected: 226563
# Percent completed:  55.400000000000006%
# Customer discarded, insufficient data: 144718
# Percent completed:  55.60000000000001%
# Customer discarded, insufficient data: 141731
# Percent completed:  55.800000000000004%
# Customer selected: 154296
# Percent completed:  56.00000000000001%
# Customer discarded, insufficient data: 270471
# Percent completed:  56.2%
# Customer discarded, insufficient data: 132451
# Percent completed:  56.39999999999999%
# Customer discarded, insufficient data: 3062
# Percent completed:  56.599999999999994%
# Customer discarded, insufficient data: 262467
# Percent completed:  56.8%
# Customer selected: 61882
# Percent completed:  56.99999999999999%
# Customer selected: 37410
# Percent completed:  57.199999999999996%
# Customer selected: 115504
# Percent completed:  57.4%
# Customer selected: 89329
# Percent completed:  57.599999999999994%
# Customer discarded, insufficient data: 265852
# Percent completed:  57.8%
# Customer discarded, insufficient data: 252030
# Percent completed:  57.99999999999999%
# Customer discarded, insufficient data: 262990
# Percent completed:  58.199999999999996%
# Customer discarded, insufficient data: 157027
# Percent completed:  58.4%
# Customer selected: 187093
# Percent completed:  58.599999999999994%
# Customer discarded, insufficient data: 177337
# Percent completed:  58.8%
# Customer discarded, insufficient data: 245427
# Percent completed:  59.0%
# Customer selected: 175451
# Percent completed:  59.199999999999996%
# Customer discarded, insufficient data: 68676
# Percent completed:  59.4%
# Customer selected: 106396
# Percent completed:  59.599999999999994%
# Customer discarded, insufficient data: 112886
# Percent completed:  59.8%
# Customer selected: 99226
# Percent completed:  60.0%
# Customer selected: 99182
# Percent completed:  60.199999999999996%
# Customer selected: 226525
# Percent completed:  60.4%
# Customer discarded, insufficient data: 92365
# Percent completed:  60.6%
# Customer selected: 194526
# Percent completed:  60.8%
# Customer discarded, insufficient data: 261759
# Percent completed:  61.0%
# Customer discarded, insufficient data: 268612
# Percent completed:  61.199999999999996%
# Customer selected: 107112
# Percent completed:  61.4%
# Customer selected: 16459
# Percent completed:  61.6%
# Customer selected: 7813
# Percent completed:  61.8%
# Customer discarded, insufficient data: 202187
# Percent completed:  62.0%
# Customer selected: 31482
# Percent completed:  62.2%
# Customer discarded, insufficient data: 55548
# Percent completed:  62.4%
# Customer selected: 97830
# Percent completed:  62.6%
# Customer discarded, insufficient data: 190613
# Percent completed:  62.8%
# Customer selected: 144554
# Percent completed:  63.0%
# Customer selected: 77256
# Percent completed:  63.2%
# Customer discarded, insufficient data: 252785
# Percent completed:  63.4%
# Customer selected: 138955
# Percent completed:  63.6%
# Customer discarded, insufficient data: 258739
# Percent completed:  63.800000000000004%
# Customer discarded, insufficient data: 194403
# Percent completed:  64.0%
# Customer selected: 209674
# Percent completed:  64.2%
# Customer selected: 151219
# Percent completed:  64.4%
# Customer discarded, insufficient data: 261987
# Percent completed:  64.60000000000001%
# Customer discarded, insufficient data: 10041
# Percent completed:  64.8%
# Customer selected: 182379
# Percent completed:  65.0%
# Customer discarded, insufficient data: 78833
# Percent completed:  65.2%
# Customer discarded, insufficient data: 267997
# Percent completed:  65.4%
# Customer discarded, insufficient data: 207269
# Percent completed:  65.60000000000001%
# Customer discarded, insufficient data: 56631
# Percent completed:  65.8%
# Customer discarded, insufficient data: 159329
# Percent completed:  66.0%
# Customer discarded, insufficient data: 98716
# Percent completed:  66.2%
# Customer discarded, insufficient data: 249532
# Percent completed:  66.4%
# Customer discarded, insufficient data: 268183
# Percent completed:  66.60000000000001%
# Customer discarded, insufficient data: 14512
# Percent completed:  66.8%
# Customer discarded, insufficient data: 95430
# Percent completed:  67.0%
# Customer selected: 219635
# Percent completed:  67.2%
# Customer discarded, insufficient data: 240212
# Percent completed:  67.4%
# Customer discarded, insufficient data: 68453
# Percent completed:  67.60000000000001%
# Customer selected: 194298
# Percent completed:  67.80000000000001%
# Customer selected: 218085
# Percent completed:  68.0%
# Customer selected: 189966
# Percent completed:  68.2%
# Customer discarded, insufficient data: 170038
# Percent completed:  68.4%
# Customer discarded, insufficient data: 236283
# Percent completed:  68.60000000000001%
# Customer selected: 113809
# Percent completed:  68.8%
# Customer selected: 47822
# Percent completed:  69.0%
# Customer selected: 61107
# Percent completed:  69.19999999999999%
# Customer selected: 12141
# Percent completed:  69.39999999999999%
# Customer discarded, insufficient data: 223167
# Percent completed:  69.6%
# Customer selected: 31877
# Percent completed:  69.8%
# Customer discarded, insufficient data: 264954
# Percent completed:  70.0%
# Customer discarded, insufficient data: 198437
# Percent completed:  70.19999999999999%
# Customer selected: 91908
# Percent completed:  70.39999999999999%
# Customer selected: 6445
# Percent completed:  70.6%
# Customer discarded, insufficient data: 43739
# Percent completed:  70.8%
# Customer discarded, insufficient data: 179867
# Percent completed:  71.0%
# Customer discarded, insufficient data: 4991
# Percent completed:  71.2%
# Customer discarded, insufficient data: 75535
# Percent completed:  71.39999999999999%
# Customer discarded, insufficient data: 19772
# Percent completed:  71.6%
# Customer selected: 53650
# Percent completed:  71.8%
# Customer discarded, insufficient data: 143299
# Percent completed:  72.0%
# Customer discarded, insufficient data: 50361
# Percent completed:  72.2%
# Customer selected: 155220
# Percent completed:  72.39999999999999%
# Customer discarded, insufficient data: 12559
# Percent completed:  72.6%
# Customer selected: 215703
# Percent completed:  72.8%
# Customer discarded, insufficient data: 241621
# Percent completed:  73.0%
# Customer selected: 158159
# Percent completed:  73.2%
# Customer discarded, insufficient data: 33031
# Percent completed:  73.4%
# Customer discarded, insufficient data: 18654
# Percent completed:  73.6%
# Customer discarded, insufficient data: 42051
# Percent completed:  73.8%
# Customer selected: 147962
# Percent completed:  74.0%
# Customer discarded, insufficient data: 249824
# Percent completed:  74.2%
# Customer discarded, insufficient data: 104130
# Percent completed:  74.4%
# Customer selected: 216655
# Percent completed:  74.6%
# Customer selected: 172366
# Percent completed:  74.8%
# Customer selected: 196177
# Percent completed:  75.0%
# Customer selected: 214797
# Percent completed:  75.2%
# Customer discarded, insufficient data: 247073
# Percent completed:  75.4%
# Customer selected: 166181
# Percent completed:  75.6%
# Customer discarded, insufficient data: 231877
# Percent completed:  75.8%
# Customer discarded, insufficient data: 80417
# Percent completed:  76.0%
# Customer discarded, insufficient data: 263487
# Percent completed:  76.2%
# Customer discarded, insufficient data: 258596
# Percent completed:  76.4%
# Customer discarded, insufficient data: 9074
# Percent completed:  76.6%
# Customer discarded, insufficient data: 272807
# Percent completed:  76.8%
# Customer selected: 234849
# Percent completed:  77.0%
# Customer discarded, insufficient data: 5216
# Percent completed:  77.2%
# Customer discarded, insufficient data: 66361
# Percent completed:  77.4%
# Customer selected: 5468
# Percent completed:  77.60000000000001%
# Customer discarded, insufficient data: 223321
# Percent completed:  77.8%
# Customer selected: 226714
# Percent completed:  78.0%
# Customer selected: 107636
# Percent completed:  78.2%
# Customer discarded, insufficient data: 231118
# Percent completed:  78.4%
# Customer discarded, insufficient data: 231477
# Percent completed:  78.60000000000001%
# Customer discarded, insufficient data: 185869
# Percent completed:  78.8%
# Customer discarded, insufficient data: 83531
# Percent completed:  79.0%
# Customer discarded, insufficient data: 173355
# Percent completed:  79.2%
# Customer selected: 60364
# Percent completed:  79.4%
# Customer discarded, insufficient data: 106213
# Percent completed:  79.60000000000001%
# Customer discarded, insufficient data: 64100
# Percent completed:  79.80000000000001%
# Customer discarded, insufficient data: 1738
# Percent completed:  80.0%
# Customer selected: 151531
# Percent completed:  80.2%
# Customer discarded, insufficient data: 255408
# Percent completed:  80.4%
# Customer selected: 142611
# Percent completed:  80.60000000000001%
# Customer discarded, insufficient data: 96230
# Percent completed:  80.80000000000001%
# Customer selected: 100566
# Percent completed:  81.0%
# Customer selected: 102070
# Percent completed:  81.2%
# Customer discarded, insufficient data: 55981
# Percent completed:  81.39999999999999%
# Customer discarded, insufficient data: 96564
# Percent completed:  81.6%
# Customer discarded, insufficient data: 4963
# Percent completed:  81.8%
# Customer selected: 119902
# Percent completed:  82.0%
# Customer discarded, insufficient data: 163947
# Percent completed:  82.19999999999999%
# Customer selected: 157557
# Percent completed:  82.39999999999999%
# Customer discarded, insufficient data: 188082
# Percent completed:  82.6%
# Customer selected: 185480
# Percent completed:  82.8%
# Customer selected: 88572
# Percent completed:  83.0%
# Customer discarded, insufficient data: 34150
# Percent completed:  83.2%
# Customer discarded, insufficient data: 66785
# Percent completed:  83.39999999999999%
# Customer discarded, insufficient data: 164598
# Percent completed:  83.6%
# Customer discarded, insufficient data: 19693
# Percent completed:  83.8%
# Customer selected: 196475
# Percent completed:  84.0%
# Customer discarded, insufficient data: 149963
# Percent completed:  84.2%
# Customer discarded, insufficient data: 177607
# Percent completed:  84.39999999999999%
# Customer discarded, insufficient data: 52287
# Percent completed:  84.6%
# Customer discarded, insufficient data: 92353
# Percent completed:  84.8%
# Customer selected: 220348
# Percent completed:  85.0%
# Customer discarded, insufficient data: 67414
# Percent completed:  85.2%
# Customer selected: 79513
# Percent completed:  85.39999999999999%
# Customer discarded, insufficient data: 244075
# Percent completed:  85.6%
# Customer discarded, insufficient data: 141912
# Percent completed:  85.8%
# Customer discarded, insufficient data: 241021
# Percent completed:  86.0%
# Customer discarded, insufficient data: 128006
# Percent completed:  86.2%
# Customer selected: 54827
# Percent completed:  86.4%
# Customer selected: 120956
# Percent completed:  86.6%
# Customer discarded, insufficient data: 68775
# Percent completed:  86.8%
# Customer discarded, insufficient data: 121465
# Percent completed:  87.0%
# Customer discarded, insufficient data: 265469
# Percent completed:  87.2%
# Customer selected: 112668
# Percent completed:  87.4%
# Customer discarded, insufficient data: 235613
# Percent completed:  87.6%
# Customer discarded, insufficient data: 155154
# Percent completed:  87.8%
# Customer selected: 218433
# Percent completed:  88.0%
# Customer selected: 166065
# Percent completed:  88.2%
# Customer discarded, insufficient data: 55017
# Percent completed:  88.4%
# Customer selected: 45446
# Percent completed:  88.6%
# Customer selected: 181199
# Percent completed:  88.8%
# Customer discarded, insufficient data: 235297
# Percent completed:  89.0%
# Customer selected: 215315
# Percent completed:  89.2%
# Customer discarded, insufficient data: 247485
# Percent completed:  89.4%
# Customer selected: 10427
# Percent completed:  89.60000000000001%
# Customer selected: 191712
# Percent completed:  89.8%
# Customer discarded, insufficient data: 149247
# Percent completed:  90.0%
# Customer selected: 186777
# Percent completed:  90.2%
# Customer selected: 68189
# Percent completed:  90.4%
# Customer discarded, insufficient data: 271718
# Percent completed:  90.60000000000001%
# Customer selected: 75719
# Percent completed:  90.8%
# Customer discarded, insufficient data: 74006
# Percent completed:  91.0%
# Customer selected: 204590
# Percent completed:  91.2%
# Customer discarded, insufficient data: 242805
# Percent completed:  91.4%
# Customer selected: 203947
# Percent completed:  91.60000000000001%
# Customer discarded, insufficient data: 263250
# Percent completed:  91.8%
# Customer selected: 192952
# Percent completed:  92.0%
# Customer selected: 95572
# Percent completed:  92.2%
# Customer discarded, insufficient data: 239207
# Percent completed:  92.4%
# Customer discarded, insufficient data: 257886
# Percent completed:  92.60000000000001%
# Customer discarded, insufficient data: 231322
# Percent completed:  92.80000000000001%
# Customer discarded, insufficient data: 262024
# Percent completed:  93.0%
# Customer discarded, insufficient data: 5812
# Percent completed:  93.2%
# Customer discarded, insufficient data: 268619
# Percent completed:  93.4%
# Customer selected: 39026
# Percent completed:  93.60000000000001%
# Customer selected: 153447
# Percent completed:  93.8%
# Customer discarded, insufficient data: 90604
# Percent completed:  94.0%
# Customer discarded, insufficient data: 262277
# Percent completed:  94.19999999999999%
# Customer discarded, insufficient data: 174051
# Percent completed:  94.39999999999999%
# Customer discarded, insufficient data: 217798
# Percent completed:  94.6%
# Customer discarded, insufficient data: 89536
# Percent completed:  94.8%
# Customer selected: 52146
# Percent completed:  95.0%
# Customer selected: 175278
# Percent completed:  95.19999999999999%
# Customer discarded, insufficient data: 140038
# Percent completed:  95.39999999999999%
# Customer discarded, insufficient data: 171476
# Percent completed:  95.6%
# Customer discarded, insufficient data: 163759
# Percent completed:  95.8%
# Customer selected: 96556
# Percent completed:  96.0%
# Customer discarded, insufficient data: 247859
# Percent completed:  96.2%
# Customer selected: 57564
# Percent completed:  96.39999999999999%
# Customer discarded, insufficient data: 42959
# Percent completed:  96.6%
# Customer selected: 58446
# Percent completed:  96.8%
# Customer selected: 146554
# Percent completed:  97.0%
# Customer discarded, insufficient data: 45668
# Percent completed:  97.2%
# Customer discarded, insufficient data: 268695
# Percent completed:  97.39999999999999%
# Customer selected: 181249
# Percent completed:  97.6%
# Customer discarded, insufficient data: 217881
# Percent completed:  97.8%
# Customer discarded, insufficient data: 134063
# Percent completed:  98.0%
# Customer discarded, insufficient data: 157697
# Percent completed:  98.2%
# Customer discarded, insufficient data: 84267
# Percent completed:  98.4%
# Customer discarded, insufficient data: 274409
# Percent completed:  98.6%
# Customer selected: 192527
# Percent completed:  98.8%
# Customer discarded, insufficient data: 17542
# Percent completed:  99.0%
# Customer discarded, insufficient data: 30379
# Percent completed:  99.2%
# Customer selected: 84389
# Percent completed:  99.4%
# Customer selected: 30101
# Percent completed:  99.6%
# Customer selected: 120512
# Percent completed:  99.8%
# Customer selected: 223348
# selectSliceByIDs terminated successfully
# Processed customers: 217
# Discarded customers: 283
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer discarded, insufficient data: 190343
# Percent completed:  0.35335689045936397%
# Customer discarded, insufficient data: 59326
# Percent completed:  0.7067137809187279%
# Customer selected: 163325
# Percent completed:  1.0600706713780919%
# Customer selected: 16978
# Percent completed:  1.4134275618374559%
# Customer discarded, insufficient data: 2239
# Percent completed:  1.76678445229682%
# Customer selected: 92340
# Percent completed:  2.1201413427561837%
# Customer discarded, insufficient data: 229959
# Percent completed:  2.4734982332155475%
# Customer selected: 55715
# Percent completed:  2.8268551236749118%
# Customer selected: 215637
# Percent completed:  3.180212014134275%
# Customer discarded, insufficient data: 255821
# Percent completed:  3.53356890459364%
# Customer selected: 177407
# Percent completed:  3.8869257950530036%
# Customer discarded, insufficient data: 85389
# Percent completed:  4.240282685512367%
# Customer discarded, insufficient data: 33067
# Percent completed:  4.593639575971731%
# Customer selected: 231011
# Percent completed:  4.946996466431095%
# Customer selected: 32570
# Percent completed:  5.30035335689046%
# Customer discarded, insufficient data: 187700
# Percent completed:  5.6537102473498235%
# Customer selected: 216104
# Percent completed:  6.007067137809187%
# Customer selected: 37447
# Percent completed:  6.36042402826855%
# Customer discarded, insufficient data: 234105
# Percent completed:  6.713780918727916%
# Customer discarded, insufficient data: 33084
# Percent completed:  7.06713780918728%
# Customer selected: 222512
# Percent completed:  7.420494699646643%
# Customer selected: 203334
# Percent completed:  7.773851590106007%
# Customer selected: 91478
# Percent completed:  8.12720848056537%
# Customer selected: 201884
# Percent completed:  8.480565371024735%
# Customer discarded, insufficient data: 232528
# Percent completed:  8.8339222614841%
# Customer discarded, insufficient data: 152392
# Percent completed:  9.187279151943462%
# Customer selected: 185968
# Percent completed:  9.540636042402827%
# Customer discarded, insufficient data: 239660
# Percent completed:  9.89399293286219%
# Customer discarded, insufficient data: 123398
# Percent completed:  10.247349823321555%
# Customer selected: 203014
# Percent completed:  10.60070671378092%
# Customer discarded, insufficient data: 59231
# Percent completed:  10.954063604240282%
# Customer discarded, insufficient data: 81432
# Percent completed:  11.307420494699647%
# Customer discarded, insufficient data: 271242
# Percent completed:  11.66077738515901%
# Customer selected: 80843
# Percent completed:  12.014134275618375%
# Customer discarded, insufficient data: 208450
# Percent completed:  12.36749116607774%
# Customer selected: 184345
# Percent completed:  12.7208480565371%
# Customer selected: 115428
# Percent completed:  13.074204946996467%
# Customer selected: 223101
# Percent completed:  13.427561837455832%
# Customer discarded, insufficient data: 165109
# Percent completed:  13.780918727915195%
# Customer selected: 80569
# Percent completed:  14.13427561837456%
# Customer discarded, insufficient data: 226061
# Percent completed:  14.487632508833922%
# Customer selected: 174898
# Percent completed:  14.840989399293287%
# Customer selected: 149509
# Percent completed:  15.19434628975265%
# Customer selected: 56762
# Percent completed:  15.547703180212014%
# Customer selected: 189397
# Percent completed:  15.901060070671377%
# Customer discarded, insufficient data: 247553
# Percent completed:  16.25441696113074%
# Customer selected: 145569
# Percent completed:  16.607773851590103%
# Customer selected: 184591
# Percent completed:  16.96113074204947%
# Customer selected: 175635
# Percent completed:  17.314487632508836%
# Customer discarded, insufficient data: 258675
# Percent completed:  17.6678445229682%
# Customer discarded, insufficient data: 267157
# Percent completed:  18.021201413427562%
# Customer discarded, insufficient data: 126011
# Percent completed:  18.374558303886925%
# Customer selected: 139565
# Percent completed:  18.727915194346288%
# Customer selected: 150395
# Percent completed:  19.081272084805654%
# Customer discarded, insufficient data: 247733
# Percent completed:  19.434628975265017%
# Customer selected: 185075
# Percent completed:  19.78798586572438%
# Customer selected: 205752
# Percent completed:  20.141342756183743%
# Customer discarded, insufficient data: 219741
# Percent completed:  20.49469964664311%
# Customer selected: 222489
# Percent completed:  20.848056537102476%
# Customer discarded, insufficient data: 252249
# Percent completed:  21.20141342756184%
# Customer discarded, insufficient data: 136921
# Percent completed:  21.554770318021202%
# Customer discarded, insufficient data: 273866
# Percent completed:  21.908127208480565%
# Customer selected: 228321
# Percent completed:  22.261484098939928%
# Customer discarded, insufficient data: 108612
# Percent completed:  22.614840989399294%
# Customer discarded, insufficient data: 177953
# Percent completed:  22.968197879858657%
# Customer discarded, insufficient data: 262242
# Percent completed:  23.32155477031802%
# Customer discarded, insufficient data: 4749
# Percent completed:  23.674911660777383%
# Customer discarded, insufficient data: 64636
# Percent completed:  24.02826855123675%
# Customer discarded, insufficient data: 245210
# Percent completed:  24.381625441696116%
# Customer selected: 106401
# Percent completed:  24.73498233215548%
# Customer selected: 151610
# Percent completed:  25.08833922261484%
# Customer selected: 76271
# Percent completed:  25.4416961130742%
# Customer discarded, insufficient data: 133251
# Percent completed:  25.795053003533567%
# Customer discarded, insufficient data: 73000
# Percent completed:  26.148409893992934%
# Customer discarded, insufficient data: 195932
# Percent completed:  26.501766784452297%
# Customer discarded, insufficient data: 139152
# Percent completed:  26.855123674911663%
# Customer selected: 114473
# Percent completed:  27.208480565371023%
# Customer discarded, insufficient data: 8122
# Percent completed:  27.56183745583039%
# Customer selected: 55197
# Percent completed:  27.915194346289752%
# Customer discarded, insufficient data: 120721
# Percent completed:  28.26855123674912%
# Customer discarded, insufficient data: 94893
# Percent completed:  28.621908127208478%
# Customer selected: 124523
# Percent completed:  28.975265017667844%
# Customer selected: 104558
# Percent completed:  29.328621908127207%
# Customer discarded, insufficient data: 73306
# Percent completed:  29.681978798586574%
# Customer discarded, insufficient data: 153233
# Percent completed:  30.03533568904594%
# Customer selected: 136790
# Percent completed:  30.3886925795053%
# Customer discarded, insufficient data: 241450
# Percent completed:  30.742049469964666%
# Customer selected: 222576
# Percent completed:  31.09540636042403%
# Customer discarded, insufficient data: 163567
# Percent completed:  31.448763250883395%
# Customer selected: 7855
# Percent completed:  31.802120141342755%
# Customer selected: 116960
# Percent completed:  32.15547703180212%
# Customer discarded, insufficient data: 211072
# Percent completed:  32.50883392226148%
# Customer selected: 74998
# Percent completed:  32.86219081272085%
# Customer selected: 229936
# Percent completed:  33.215547703180206%
# Customer selected: 145344
# Percent completed:  33.56890459363957%
# Customer selected: 167257
# Percent completed:  33.92226148409894%
# Customer discarded, insufficient data: 49643
# Percent completed:  34.275618374558306%
# Customer discarded, insufficient data: 52283
# Percent completed:  34.62897526501767%
# Customer selected: 120702
# Percent completed:  34.98233215547703%
# Customer discarded, insufficient data: 47211
# Percent completed:  35.3356890459364%
# Customer selected: 209936
# Percent completed:  35.68904593639576%
# Customer discarded, insufficient data: 82531
# Percent completed:  36.042402826855124%
# Customer selected: 41769
# Percent completed:  36.39575971731448%
# Customer selected: 233041
# Percent completed:  36.74911660777385%
# Customer selected: 186801
# Percent completed:  37.102473498233216%
# Customer discarded, insufficient data: 217262
# Percent completed:  37.455830388692576%
# Customer selected: 211061
# Percent completed:  37.80918727915194%
# Customer selected: 112403
# Percent completed:  38.16254416961131%
# Customer discarded, insufficient data: 217703
# Percent completed:  38.515901060070675%
# Customer selected: 44391
# Percent completed:  38.869257950530034%
# Customer selected: 204036
# Percent completed:  39.2226148409894%
# Customer selected: 84643
# Percent completed:  39.57597173144876%
# Customer discarded, insufficient data: 220201
# Percent completed:  39.92932862190813%
# Customer discarded, insufficient data: 72412
# Percent completed:  40.282685512367486%
# Customer discarded, insufficient data: 73103
# Percent completed:  40.63604240282685%
# Customer selected: 180250
# Percent completed:  40.98939929328622%
# Customer discarded, insufficient data: 60415
# Percent completed:  41.342756183745585%
# Customer selected: 76849
# Percent completed:  41.69611307420495%
# Customer discarded, insufficient data: 39263
# Percent completed:  42.04946996466431%
# Customer discarded, insufficient data: 239337
# Percent completed:  42.40282685512368%
# Customer selected: 104386
# Percent completed:  42.75618374558304%
# Customer discarded, insufficient data: 173583
# Percent completed:  43.109540636042404%
# Customer discarded, insufficient data: 59041
# Percent completed:  43.46289752650176%
# Customer selected: 80876
# Percent completed:  43.81625441696113%
# Customer discarded, insufficient data: 180782
# Percent completed:  44.16961130742049%
# Customer discarded, insufficient data: 52620
# Percent completed:  44.522968197879855%
# Customer selected: 77489
# Percent completed:  44.87632508833922%
# Customer selected: 148737
# Percent completed:  45.22968197879859%
# Customer discarded, insufficient data: 89583
# Percent completed:  45.583038869257955%
# Customer selected: 192780
# Percent completed:  45.936395759717314%
# Customer selected: 150197
# Percent completed:  46.28975265017668%
# Customer discarded, insufficient data: 253318
# Percent completed:  46.64310954063604%
# Customer discarded, insufficient data: 232651
# Percent completed:  46.996466431095406%
# Customer selected: 67789
# Percent completed:  47.349823321554766%
# Customer selected: 5294
# Percent completed:  47.70318021201413%
# Customer discarded, insufficient data: 27319
# Percent completed:  48.0565371024735%
# Customer selected: 136818
# Percent completed:  48.409893992932865%
# Customer discarded, insufficient data: 189400
# Percent completed:  48.76325088339223%
# Customer discarded, insufficient data: 270742
# Percent completed:  49.11660777385159%
# Customer selected: 186563
# Percent completed:  49.46996466431096%
# Customer selected: 131127
# Percent completed:  49.82332155477032%
# Customer discarded, insufficient data: 252158
# Percent completed:  50.17667844522968%
# Customer selected: 19629
# Percent completed:  50.53003533568905%
# Customer selected: 155991
# Percent completed:  50.8833922261484%
# Customer discarded, insufficient data: 122968
# Percent completed:  51.23674911660777%
# Customer discarded, insufficient data: 259168
# Percent completed:  51.590106007067135%
# Customer selected: 221764
# Percent completed:  51.9434628975265%
# Customer discarded, insufficient data: 184726
# Percent completed:  52.29681978798587%
# Customer discarded, insufficient data: 224213
# Percent completed:  52.65017667844523%
# Customer selected: 228904
# Percent completed:  53.003533568904594%
# Customer discarded, insufficient data: 185390
# Percent completed:  53.35689045936396%
# Customer discarded, insufficient data: 217383
# Percent completed:  53.71024734982333%
# Customer selected: 79641
# Percent completed:  54.06360424028268%
# Customer selected: 193987
# Percent completed:  54.416961130742045%
# Customer discarded, insufficient data: 116649
# Percent completed:  54.77031802120141%
# Customer selected: 141818
# Percent completed:  55.12367491166078%
# Customer selected: 15835
# Percent completed:  55.47703180212014%
# Customer selected: 18019
# Percent completed:  55.830388692579504%
# Customer selected: 61788
# Percent completed:  56.18374558303887%
# Customer discarded, insufficient data: 84301
# Percent completed:  56.53710247349824%
# Customer selected: 99042
# Percent completed:  56.8904593639576%
# Customer discarded, insufficient data: 256433
# Percent completed:  57.243816254416956%
# Customer discarded, insufficient data: 261902
# Percent completed:  57.59717314487632%
# Customer discarded, insufficient data: 180450
# Percent completed:  57.95053003533569%
# Customer selected: 103216
# Percent completed:  58.303886925795055%
# Customer selected: 215751
# Percent completed:  58.657243816254415%
# Customer discarded, insufficient data: 225352
# Percent completed:  59.01060070671378%
# Customer selected: 16535
# Percent completed:  59.36395759717315%
# Customer selected: 103211
# Percent completed:  59.717314487632514%
# Customer discarded, insufficient data: 16525
# Percent completed:  60.07067137809188%
# Customer discarded, insufficient data: 220372
# Percent completed:  60.42402826855123%
# Customer discarded, insufficient data: 275339
# Percent completed:  60.7773851590106%
# Customer selected: 161092
# Percent completed:  61.130742049469966%
# Customer discarded, insufficient data: 204872
# Percent completed:  61.48409893992933%
# Customer discarded, insufficient data: 37080
# Percent completed:  61.83745583038869%
# Customer discarded, insufficient data: 122466
# Percent completed:  62.19081272084806%
# Customer selected: 185358
# Percent completed:  62.544169611307424%
# Customer discarded, insufficient data: 191616
# Percent completed:  62.89752650176679%
# Customer discarded, insufficient data: 116711
# Percent completed:  63.25088339222616%
# Customer selected: 164514
# Percent completed:  63.60424028268551%
# Customer selected: 160780
# Percent completed:  63.957597173144876%
# Customer discarded, insufficient data: 239829
# Percent completed:  64.31095406360424%
# Customer discarded, insufficient data: 273383
# Percent completed:  64.66431095406361%
# Customer selected: 140166
# Percent completed:  65.01766784452296%
# Customer discarded, insufficient data: 233734
# Percent completed:  65.37102473498233%
# Customer discarded, insufficient data: 59194
# Percent completed:  65.7243816254417%
# Customer selected: 103998
# Percent completed:  66.07773851590106%
# Customer discarded, insufficient data: 32026
# Percent completed:  66.43109540636041%
# Customer discarded, insufficient data: 277704
# Percent completed:  66.78445229681978%
# Customer selected: 11200
# Percent completed:  67.13780918727915%
# Customer discarded, insufficient data: 273797
# Percent completed:  67.49116607773851%
# Customer discarded, insufficient data: 141518
# Percent completed:  67.84452296819788%
# Customer discarded, insufficient data: 42092
# Percent completed:  68.19787985865725%
# Customer selected: 65484
# Percent completed:  68.55123674911661%
# Customer selected: 29725
# Percent completed:  68.90459363957598%
# Customer discarded, insufficient data: 274582
# ...
# Customer selected: 218379
# Percent completed:  65.1006711409396%
# Customer discarded, insufficient data: 273872
# Percent completed:  65.77181208053692%
# Customer discarded, insufficient data: 122630
# Percent completed:  66.44295302013423%
# Customer discarded, insufficient data: 82106
# Percent completed:  67.11409395973155%
# Customer selected: 218373
# Percent completed:  67.78523489932886%
# Customer selected: 78037
# Percent completed:  68.45637583892618%
# Customer discarded, insufficient data: 70813
# Percent completed:  69.12751677852349%
# Customer selected: 59118
# Percent completed:  69.79865771812081%
# Customer discarded, insufficient data: 241047
# Percent completed:  70.46979865771812%
# Customer selected: 216223
# Percent completed:  71.14093959731544%
# Customer selected: 207171
# Percent completed:  71.81208053691275%
# Customer selected: 32710
# Percent completed:  72.48322147651007%
# Customer discarded, insufficient data: 55094
# Percent completed:  73.15436241610739%
# Customer discarded, insufficient data: 250400
# Percent completed:  73.8255033557047%
# Customer discarded, insufficient data: 252819
# Percent completed:  74.49664429530202%
# Customer discarded, insufficient data: 56297
# Percent completed:  75.16778523489933%
# Customer discarded, insufficient data: 216148
# Percent completed:  75.83892617449665%
# Customer selected: 183642
# Percent completed:  76.51006711409396%
# Customer discarded, insufficient data: 253419
# Percent completed:  77.18120805369128%
# Customer discarded, insufficient data: 42809
# Percent completed:  77.85234899328859%
# Customer discarded, insufficient data: 115461
# Percent completed:  78.52348993288591%
# Customer discarded, insufficient data: 177750
# Percent completed:  79.19463087248322%
# Customer discarded, insufficient data: 255872
# Percent completed:  79.86577181208054%
# Customer selected: 71364
# Percent completed:  80.53691275167785%
# Customer discarded, insufficient data: 245536
# Percent completed:  81.20805369127517%
# Customer selected: 70329
# Percent completed:  81.87919463087249%
# Customer selected: 138288
# Percent completed:  82.5503355704698%
# Customer discarded, insufficient data: 149255
# Percent completed:  83.22147651006712%
# Customer selected: 107837
# Percent completed:  83.89261744966443%
# Customer selected: 62253
# Percent completed:  84.56375838926175%
# Customer selected: 127667
# Percent completed:  85.23489932885906%
# Customer selected: 209389
# Percent completed:  85.90604026845638%
# Customer discarded, insufficient data: 192758
# Percent completed:  86.57718120805369%
# Customer discarded, insufficient data: 260710
# Percent completed:  87.24832214765101%
# Customer discarded, insufficient data: 274930
# Percent completed:  87.91946308724832%
# Customer selected: 114646
# Percent completed:  88.59060402684564%
# Customer discarded, insufficient data: 191046
# Percent completed:  89.26174496644296%
# Customer selected: 79356
# Percent completed:  89.93288590604027%
# Customer discarded, insufficient data: 92503
# Percent completed:  90.60402684563759%
# Customer selected: 126345
# Percent completed:  91.2751677852349%
# Customer discarded, insufficient data: 272512
# Percent completed:  91.94630872483222%
# Customer discarded, insufficient data: 252115
# Percent completed:  92.61744966442953%
# Customer selected: 189588
# Percent completed:  93.28859060402685%
# Customer selected: 166842
# Percent completed:  93.95973154362416%
# Customer selected: 63817
# Percent completed:  94.63087248322147%
# Customer discarded, insufficient data: 233036
# Percent completed:  95.30201342281879%
# Customer selected: 200025
# Percent completed:  95.9731543624161%
# Customer discarded, insufficient data: 88410
# Percent completed:  96.64429530201343%
# Customer selected: 164074
# Percent completed:  97.31543624161074%
# Customer discarded, insufficient data: 71986
# Percent completed:  97.98657718120806%
# Customer selected: 176997
# Percent completed:  98.65771812080537%
# Customer selected: 181761
# Percent completed:  99.32885906040269%
# Customer selected: 86316
# selectSliceByIDs terminated successfully
# Processed customers: 80
# Discarded customers: 69
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer selected: 116027
# Percent completed:  1.4492753623188406%
# Customer selected: 57738
# Percent completed:  2.898550724637681%
# Customer discarded, insufficient data: 247739
# Percent completed:  4.3478260869565215%
# Customer discarded, insufficient data: 40090
# Percent completed:  5.797101449275362%
# Customer selected: 171374
# Percent completed:  7.246376811594203%
# Customer discarded, insufficient data: 232148
# Percent completed:  8.695652173913043%
# Customer discarded, insufficient data: 90090
# Percent completed:  10.144927536231885%
# Customer selected: 158961
# Percent completed:  11.594202898550725%
# Customer selected: 59783
# Percent completed:  13.043478260869565%
# Customer discarded, insufficient data: 275427
# Percent completed:  14.492753623188406%
# Customer discarded, insufficient data: 76892
# Percent completed:  15.942028985507244%
# Customer selected: 88799
# Percent completed:  17.391304347826086%
# Customer selected: 184382
# Percent completed:  18.84057971014493%
# Customer discarded, insufficient data: 94442
# Percent completed:  20.28985507246377%
# Customer selected: 98081
# Percent completed:  21.73913043478261%
# Customer selected: 189959
# Percent completed:  23.18840579710145%
# Customer discarded, insufficient data: 90131
# Percent completed:  24.637681159420293%
# Customer discarded, insufficient data: 18155
# Percent completed:  26.08695652173913%
# Customer discarded, insufficient data: 195387
# Percent completed:  27.536231884057973%
# Customer discarded, insufficient data: 255923
# Percent completed:  28.985507246376812%
# Customer discarded, insufficient data: 100762
# Percent completed:  30.434782608695656%
# Customer discarded, insufficient data: 99268
# Percent completed:  31.88405797101449%
# Customer selected: 81906
# Percent completed:  33.33333333333333%
# Customer selected: 181029
# Percent completed:  34.78260869565217%
# Customer selected: 142920
# Percent completed:  36.231884057971016%
# Customer selected: 191066
# Percent completed:  37.68115942028986%
# Customer discarded, insufficient data: 257482
# Percent completed:  39.130434782608695%
# Customer discarded, insufficient data: 1566
# Percent completed:  40.57971014492754%
# Customer discarded, insufficient data: 56278
# Percent completed:  42.028985507246375%
# Customer discarded, insufficient data: 14548
# Percent completed:  43.47826086956522%
# Customer selected: 193076
# Percent completed:  44.927536231884055%
# Customer selected: 68313
# Percent completed:  46.3768115942029%
# Customer selected: 94391
# Percent completed:  47.82608695652174%
# Customer discarded, insufficient data: 266902
# Percent completed:  49.275362318840585%
# Customer selected: 203025
# Percent completed:  50.72463768115942%
# Customer selected: 161098
# Percent completed:  52.17391304347826%
# Customer selected: 88145
# Percent completed:  53.62318840579711%
# Customer discarded, insufficient data: 51778
# Percent completed:  55.072463768115945%
# Customer selected: 172116
# Percent completed:  56.52173913043478%
# Customer selected: 217715
# Percent completed:  57.971014492753625%
# Customer selected: 116905
# Percent completed:  59.42028985507246%
# Customer discarded, insufficient data: 33475
# Percent completed:  60.86956521739131%
# Customer discarded, insufficient data: 95273
# Percent completed:  62.31884057971014%
# Customer selected: 30320
# Percent completed:  63.76811594202898%
# Customer discarded, insufficient data: 75631
# Percent completed:  65.21739130434783%
# Customer selected: 51052
# Percent completed:  66.66666666666666%
# Customer selected: 221251
# Percent completed:  68.11594202898551%
# Customer discarded, insufficient data: 103938
# Percent completed:  69.56521739130434%
# Customer selected: 155868
# Percent completed:  71.01449275362319%
# Customer selected: 138807
# Percent completed:  72.46376811594203%
# Customer discarded, insufficient data: 206998
# Percent completed:  73.91304347826086%
# Customer discarded, insufficient data: 76641
# Percent completed:  75.36231884057972%
# Customer selected: 126341
# Percent completed:  76.81159420289855%
# Customer selected: 86715
# Percent completed:  78.26086956521739%
# Customer discarded, insufficient data: 56875
# Percent completed:  79.71014492753623%
# Customer discarded, insufficient data: 52704
# Percent completed:  81.15942028985508%
# Customer selected: 148201
# Percent completed:  82.6086956521739%
# Customer discarded, insufficient data: 17652
# Percent completed:  84.05797101449275%
# Customer discarded, insufficient data: 230866
# Percent completed:  85.5072463768116%
# Customer selected: 27329
# Percent completed:  86.95652173913044%
# Customer discarded, insufficient data: 236628
# Percent completed:  88.40579710144928%
# Customer discarded, insufficient data: 70984
# Percent completed:  89.85507246376811%
# Customer discarded, insufficient data: 247542
# Percent completed:  91.30434782608695%
# Customer discarded, insufficient data: 208932
# Percent completed:  92.7536231884058%
# Customer selected: 13825
# Percent completed:  94.20289855072464%
# Customer selected: 75174
# Percent completed:  95.65217391304348%
# Customer selected: 203884
# Percent completed:  97.10144927536231%
# Customer selected: 197717
# Percent completed:  98.55072463768117%
# Customer selected: 214033
# selectSliceByIDs terminated successfully
# Processed customers: 36
# Discarded customers: 33
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer discarded, insufficient data: 250943
# Percent completed:  3.0303030303030303%
# Customer discarded, insufficient data: 167091
# Percent completed:  6.0606060606060606%
# Customer selected: 195426
# Percent completed:  9.090909090909092%
# Customer discarded, insufficient data: 201672
# Percent completed:  12.121212121212121%
# Customer discarded, insufficient data: 81501
# Percent completed:  15.151515151515152%
# Customer selected: 8995
# Percent completed:  18.181818181818183%
# Customer discarded, insufficient data: 138322
# Percent completed:  21.21212121212121%
# Customer selected: 130861
# Percent completed:  24.242424242424242%
# Customer selected: 229632
# Percent completed:  27.27272727272727%
# Customer selected: 167787
# Percent completed:  30.303030303030305%
# Customer selected: 228350
# Percent completed:  33.33333333333333%
# Customer discarded, insufficient data: 164838
# Percent completed:  36.36363636363637%
# Customer selected: 31111
# Percent completed:  39.39393939393939%
# Customer selected: 33003
# Percent completed:  42.42424242424242%
# Customer discarded, insufficient data: 88386
# Percent completed:  45.45454545454545%
# Customer discarded, insufficient data: 281407
# Percent completed:  48.484848484848484%
# Customer discarded, insufficient data: 82058
# Percent completed:  51.515151515151516%
# Customer discarded, insufficient data: 171230
# Percent completed:  54.54545454545454%
# Customer discarded, insufficient data: 100397
# Percent completed:  57.57575757575758%
# Customer selected: 181934
# Percent completed:  60.60606060606061%
# Customer selected: 209965
# Percent completed:  63.63636363636363%
# Customer discarded, insufficient data: 220022
# Percent completed:  66.66666666666666%
# Customer discarded, insufficient data: 263026
# Percent completed:  69.6969696969697%
# Customer selected: 13415
# Percent completed:  72.72727272727273%
# Customer selected: 220482
# Percent completed:  75.75757575757575%
# Customer discarded, insufficient data: 50115
# Percent completed:  78.78787878787878%
# Customer discarded, insufficient data: 253089
# Percent completed:  81.81818181818183%
# Customer discarded, insufficient data: 16827
# Percent completed:  84.84848484848484%
# Customer discarded, insufficient data: 256044
# Percent completed:  87.87878787878788%
# Customer selected: 173941
# Percent completed:  90.9090909090909%
# Customer discarded, insufficient data: 269437
# Percent completed:  93.93939393939394%
# Customer discarded, insufficient data: 267983
# Percent completed:  96.96969696969697%
# Customer discarded, insufficient data: 89997
# selectSliceByIDs terminated successfully
# Processed customers: 13
# Discarded customers: 20
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer discarded, insufficient data: 264924
# Percent completed:  5.0%
# Customer selected: 190369
# Percent completed:  10.0%
# Customer selected: 43166
# Percent completed:  15.0%
# Customer discarded, insufficient data: 122841
# Percent completed:  20.0%
# Customer discarded, insufficient data: 200481
# Percent completed:  25.0%
# Customer discarded, insufficient data: 43825
# Percent completed:  30.0%
# Customer discarded, insufficient data: 13329
# Percent completed:  35.0%
# Customer selected: 218073
# Percent completed:  40.0%
# Customer discarded, insufficient data: 248724
# Percent completed:  45.0%
# Customer discarded, insufficient data: 271845
# Percent completed:  50.0%
# Customer selected: 161625
# Percent completed:  55.00000000000001%
# Customer selected: 104439
# Percent completed:  60.0%
# Customer selected: 99131
# Percent completed:  65.0%
# Customer discarded, insufficient data: 268300
# Percent completed:  70.0%
# Customer discarded, insufficient data: 180141
# Percent completed:  75.0%
# Customer discarded, insufficient data: 130853
# Percent completed:  80.0%
# Customer discarded, insufficient data: 32120
# Percent completed:  85.0%
# Customer discarded, insufficient data: 32721
# Percent completed:  90.0%
# Customer discarded, insufficient data: 276157
# Percent completed:  95.0%
# Customer selected: 188365
# selectSliceByIDs terminated successfully
# Processed customers: 7
# Discarded customers: 13
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer selected: 200344
# Percent completed:  7.6923076923076925%
# Customer selected: 207451
# Percent completed:  15.384615384615385%
# Customer discarded, insufficient data: 79628
# Percent completed:  23.076923076923077%
# Customer discarded, insufficient data: 65202
# Percent completed:  30.76923076923077%
# Customer selected: 30256
# Percent completed:  38.46153846153847%
# Customer discarded, insufficient data: 247886
# Percent completed:  46.15384615384615%
# Customer selected: 1982
# Percent completed:  53.84615384615385%
# Customer selected: 160137
# Percent completed:  61.53846153846154%
# Customer discarded, insufficient data: 64283
# Percent completed:  69.23076923076923%
# Customer selected: 95280
# Percent completed:  76.92307692307693%
# Customer selected: 80667
# Percent completed:  84.61538461538461%
# Customer discarded, insufficient data: 13589
# Percent completed:  92.3076923076923%
# Customer discarded, insufficient data: 11444
# selectSliceByIDs terminated successfully
# Processed customers: 7
# Discarded customers: 6
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer discarded, insufficient data: 57378
# Percent completed:  16.666666666666664%
# Customer selected: 87407
# Percent completed:  33.33333333333333%
# Customer selected: 88181
# Percent completed:  50.0%
# Customer discarded, insufficient data: 205562
# Percent completed:  66.66666666666666%
# Customer discarded, insufficient data: 259443
# Percent completed:  83.33333333333334%
# Customer selected: 212567
# selectSliceByIDs terminated successfully
# Processed customers: 3
# Discarded customers: 3
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer discarded, insufficient data: 54445
# Percent completed:  33.33333333333333%
# Customer discarded, insufficient data: 262548
# Percent completed:  66.66666666666666%
# Customer selected: 1242
# selectSliceByIDs terminated successfully
# Processed customers: 1
# Discarded customers: 2
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer discarded, insufficient data: 29091
# Percent completed:  50.0%
# Customer selected: 170544
# selectSliceByIDs terminated successfully
# Processed customers: 1
# Discarded customers: 1
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer discarded, insufficient data: 227240
# selectSliceByIDs terminated successfully
# Processed customers: 0
# Discarded customers: 1
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer discarded, insufficient data: 270934
# selectSliceByIDs terminated successfully
# Processed customers: 0
# Discarded customers: 1
# Selecting slice by IDs...
# Percent completed:  0.0%
# Customer selected: 122254
# selectSliceByIDs terminated successfully
# Processed customers: 1
# Discarded customers: 0

# %%
my_algorithms_table = pd.DataFrame(columns=['name', 'algorithm'])
my_algorithms_table['name'] = ['rf']
my_algorithms_table['algorithm'] = [RandomForestRegressor(n_estimators=150, min_samples_split=2)]
my_train_columns = ['tavg_intervalSum', 'prev_pd_kwh', 'prev_prev_pd_kwh', 'days_passed', 'iethicalid', 'avg_kwh']
my_categorical_columns = ['month']
my_interaction_columns = [('month', 'tavg_intervalSum', 'categorical', 'numerical')]

# %%
cust_slice.run_aggregate_models(my_train_columns, my_categorical_columns, my_interaction_columns, 'kwh', my_algorithms_table)

# %%
cust_slice.agg_errorFrame
# Out:
#   regression approach RMSQE     AE     MAE
# 0    predicted_kwh_rf     0  94865  189.73

# %%
my_train_columns = ['tavg_intervalSum', 'prev_pd_kwh', 'prev_prev_pd_kwh', 'days_passed']
my_categorical_columns = ['month']

# %%
cust_slice.runModels(my_train_columns, my_categorical_columns, 'kwh', my_algorithms_table)
# Out:
# Percent completed:  0.2%
# Percent completed:  0.4%
# Percent completed:  0.6%
# Percent completed:  0.8%
# Percent completed:  1.0%
# Percent completed:  1.2%
# Percent completed:  1.4000000000000001%
# Percent completed:  1.6%
# Percent completed:  1.7999999999999998%
# Percent completed:  2.0%
# Percent completed:  2.1999999999999997%
# Percent completed:  2.4%
# Percent completed:  2.6%
# Percent completed:  2.8000000000000003%
# Percent completed:  3.0%
# Percent completed:  3.2%
# Percent completed:  3.4000000000000004%
# Percent completed:  3.5999999999999996%
# Percent completed:  3.8%
# Percent completed:  4.0%
# Percent completed:  4.2%
# Percent completed:  4.3999999999999995%
# Percent completed:  4.6%
# Percent completed:  4.8%
# Percent completed:  5.0%
# Percent completed:  5.2%
# Percent completed:  5.4%
# Percent completed:  5.6000000000000005%
# Percent completed:  5.800000000000001%
# Percent completed:  6.0%
# Percent completed:  6.2%
# Percent completed:  6.4%
# Percent completed:  6.6000000000000005%
# Percent completed:  6.800000000000001%
# Percent completed:  7.000000000000001%
# Percent completed:  7.199999999999999%
# Percent completed:  7.3999999999999995%
# Percent completed:  7.6%
# Percent completed:  7.8%
# Percent completed:  8.0%
# Percent completed:  8.200000000000001%
# Percent completed:  8.4%
# Percent completed:  8.6%
# Percent completed:  8.799999999999999%
# Percent completed:  9.0%
# Percent completed:  9.2%
# Percent completed:  9.4%
# Percent completed:  9.6%
# Percent completed:  9.8%
# Percent completed:  10.0%
# Percent completed:  10.2%
# Percent completed:  10.4%
# Percent completed:  10.6%
# Percent completed:  10.8%
# Percent completed:  11.0%
# Percent completed:  11.200000000000001%
# Percent completed:  11.4%
# Percent completed:  11.600000000000001%
# Percent completed:  11.799999999999999%
# Percent completed:  12.0%
# Percent completed:  12.2%
# Percent completed:  12.4%
# Percent completed:  12.6%
# Percent completed:  12.8%
# Percent completed:  13.0%
# Percent completed:  13.200000000000001%
# Percent completed:  13.4%
# Percent completed:  13.600000000000001%
# Percent completed:  13.8%
# Percent completed:  14.000000000000002%
# Percent completed:  14.2%
# Percent completed:  14.399999999999999%
# Percent completed:  14.6%
# Percent completed:  14.799999999999999%
# Percent completed:  15.0%
# Percent completed:  15.2%
# Percent completed:  15.4%
# Percent completed:  15.6%
# Percent completed:  15.8%
# Percent completed:  16.0%
# Percent completed:  16.2%
# Percent completed:  16.400000000000002%
# Percent completed:  16.6%
# Percent completed:  16.8%
# Percent completed:  17.0%
# Percent completed:  17.2%
# Percent completed:  17.4%
# Percent completed:  17.599999999999998%
# Percent completed:  17.8%
# Percent completed:  18.0%
# Percent completed:  18.2%
# Percent completed:  18.4%
# Percent completed:  18.6%
# Percent completed:  18.8%
# Percent completed:  19.0%
# Percent completed:  19.2%
# Percent completed:  19.400000000000002%
# Percent completed:  19.6%
# Percent completed:  19.8%
# Percent completed:  20.0%
# Percent completed:  20.200000000000003%
# Percent completed:  20.4%
# Percent completed:  20.599999999999998%
# Percent completed:  20.8%
# Percent completed:  21.0%
# Percent completed:  21.2%
# Percent completed:  21.4%
# Percent completed:  21.6%
# Percent completed:  21.8%
# Percent completed:  22.0%
# Percent completed:  22.2%
# Percent completed:  22.400000000000002%
# Percent completed:  22.6%
# Percent completed:  22.8%
# Percent completed:  23.0%
# Percent completed:  23.200000000000003%
# Percent completed:  23.400000000000002%
# Percent completed:  23.599999999999998%
# Percent completed:  23.799999999999997%
# Percent completed:  24.0%
# Percent completed:  24.2%
# Percent completed:  24.4%
# Percent completed:  24.6%
# Percent completed:  24.8%
# Percent completed:  25.0%
# Percent completed:  25.2%
# Percent completed:  25.4%
# Percent completed:  25.6%
# Percent completed:  25.8%
# Percent completed:  26.0%
# Percent completed:  26.200000000000003%
# Percent completed:  26.400000000000002%
# Percent completed:  26.6%
# Percent completed:  26.8%
# Percent completed:  27.0%
# Percent completed:  27.200000000000003%
# Percent completed:  27.400000000000002%
# Percent completed:  27.6%
# Percent completed:  27.800000000000004%
# Percent completed:  28.000000000000004%
# Percent completed:  28.199999999999996%
# Percent completed:  28.4%
# Percent completed:  28.599999999999998%
# Percent completed:  28.799999999999997%
# Percent completed:  28.999999999999996%
# Percent completed:  29.2%
# Percent completed:  29.4%
# Percent completed:  29.599999999999998%
# Percent completed:  29.799999999999997%
# Percent completed:  30.0%
# Percent completed:  30.2%
# Percent completed:  30.4%
# Percent completed:  30.599999999999998%
# Percent completed:  30.8%
# Percent completed:  31.0%
# Percent completed:  31.2%
# Percent completed:  31.4%
# Percent completed:  31.6%
# Percent completed:  31.8%
# Percent completed:  32.0%
# Percent completed:  32.2%
# Percent completed:  32.4%
# Percent completed:  32.6%
# Percent completed:  32.800000000000004%
# Percent completed:  33.0%
# Percent completed:  33.2%
# Percent completed:  33.4%
# Percent completed:  33.6%
# Percent completed:  33.800000000000004%
# Percent completed:  34.0%
# Percent completed:  34.2%
# Percent completed:  34.4%
# Percent completed:  34.599999999999994%
# Percent completed:  34.8%
# Percent completed:  35.0%
# Percent completed:  35.199999999999996%
# Percent completed:  35.4%
# Percent completed:  35.6%
# Percent completed:  35.8%
# Percent completed:  36.0%
# Percent completed:  36.199999999999996%
# Percent completed:  36.4%
# Percent completed:  36.6%
# Percent completed:  36.8%
# Percent completed:  37.0%
# Percent completed:  37.2%
# Percent completed:  37.4%
# Percent completed:  37.6%
# Percent completed:  37.8%
# Percent completed:  38.0%
# Percent completed:  38.2%
# Percent completed:  38.4%
# Percent completed:  38.6%
# Percent completed:  38.800000000000004%
# Percent completed:  39.0%
# Percent completed:  39.2%
# Percent completed:  39.4%
# Percent completed:  39.6%
# Percent completed:  39.800000000000004%
# Percent completed:  40.0%
# Percent completed:  40.2%
# Percent completed:  40.400000000000006%
# Percent completed:  40.6%
# Percent completed:  40.8%
# Percent completed:  41.0%
# Percent completed:  41.199999999999996%
# Percent completed:  41.4%
# Percent completed:  41.6%
# Percent completed:  41.8%
# Percent completed:  42.0%
# Percent completed:  42.199999999999996%
# Percent completed:  42.4%
# Percent completed:  42.6%
# Percent completed:  42.8%
# Percent completed:  43.0%
# Percent completed:  43.2%
# Percent completed:  43.4%
# Percent completed:  43.6%
# Percent completed:  43.8%
# Percent completed:  44.0%
# Percent completed:  44.2%
# Percent completed:  44.4%
# Percent completed:  44.6%
# Percent completed:  44.800000000000004%
# Percent completed:  45.0%
# Percent completed:  45.2%
# Percent completed:  45.4%
# Percent completed:  45.6%
# Percent completed:  45.800000000000004%
# Percent completed:  46.0%
# Percent completed:  46.2%
# Percent completed:  46.400000000000006%
# Percent completed:  46.6%
# Percent completed:  46.800000000000004%
# Percent completed:  47.0%
# Percent completed:  47.199999999999996%
# Percent completed:  47.4%
# Percent completed:  47.599999999999994%
# Percent completed:  47.8%
# Percent completed:  48.0%
# Percent completed:  48.199999999999996%
# Percent completed:  48.4%
# Percent completed:  48.6%
# Percent completed:  48.8%
# Percent completed:  49.0%
# Percent completed:  49.2%
# Percent completed:  49.4%
# Percent completed:  49.6%
# Percent completed:  49.8%
# Percent completed:  50.0%
# Percent completed:  50.2%
# Percent completed:  50.4%
# Percent completed:  50.6%
# Percent completed:  50.8%
# Percent completed:  51.0%
# Percent completed:  51.2%
# Percent completed:  51.4%
# Percent completed:  51.6%
# Percent completed:  51.800000000000004%
# Percent completed:  52.0%
# Percent completed:  52.2%
# Percent completed:  52.400000000000006%
# Percent completed:  52.6%
# Percent completed:  52.800000000000004%
# Percent completed:  53.0%
# Percent completed:  53.2%
# Percent completed:  53.400000000000006%
# Percent completed:  53.6%
# Percent completed:  53.800000000000004%
# Percent completed:  54.0%
# Percent completed:  54.2%
# Percent completed:  54.400000000000006%
# Percent completed:  54.6%
# Percent completed:  54.800000000000004%
# Percent completed:  55.00000000000001%
# Percent completed:  55.2%
# Percent completed:  55.400000000000006%
# Percent completed:  55.60000000000001%
# Percent completed:  55.800000000000004%
# Percent completed:  56.00000000000001%
# Percent completed:  56.2%
# Percent completed:  56.39999999999999%
# Percent completed:  56.599999999999994%
# Percent completed:  56.8%
# Percent completed:  56.99999999999999%
# Percent completed:  57.199999999999996%
# Percent completed:  57.4%
# Percent completed:  57.599999999999994%
# Percent completed:  57.8%
# Percent completed:  57.99999999999999%
# Percent completed:  58.199999999999996%
# Percent completed:  58.4%
# Percent completed:  58.599999999999994%
# Percent completed:  58.8%
# Percent completed:  59.0%
# Percent completed:  59.199999999999996%
# Percent completed:  59.4%
# Percent completed:  59.599999999999994%
# Percent completed:  59.8%
# Percent completed:  60.0%
# Percent completed:  60.199999999999996%
# Percent completed:  60.4%
# Percent completed:  60.6%
# Percent completed:  60.8%
# Percent completed:  61.0%
# Percent completed:  61.199999999999996%
# Percent completed:  61.4%
# Percent completed:  61.6%
# Percent completed:  61.8%
# Percent completed:  62.0%
# Percent completed:  62.2%
# Percent completed:  62.4%
# Percent completed:  62.6%
# Percent completed:  62.8%
# Percent completed:  63.0%
# Percent completed:  63.2%
# Percent completed:  63.4%
# Percent completed:  63.6%
# Percent completed:  63.800000000000004%
# Percent completed:  64.0%
# Percent completed:  64.2%
# Percent completed:  64.4%
# Percent completed:  64.60000000000001%
# Percent completed:  64.8%
# Percent completed:  65.0%
# Percent completed:  65.2%
# Percent completed:  65.4%
# Percent completed:  65.60000000000001%
# Percent completed:  65.8%
# Percent completed:  66.0%
# Percent completed:  66.2%
# Percent completed:  66.4%
# Percent completed:  66.60000000000001%
# Percent completed:  66.8%
# Percent completed:  67.0%
# Percent completed:  67.2%
# Percent completed:  67.4%
# Percent completed:  67.60000000000001%
# Percent completed:  67.80000000000001%
# Percent completed:  68.0%
# Percent completed:  68.2%
# Percent completed:  68.4%
# Percent completed:  68.60000000000001%
# Percent completed:  68.8%
# Percent completed:  69.0%
# Percent completed:  69.19999999999999%
# Percent completed:  69.39999999999999%
# Percent completed:  69.6%
# Percent completed:  69.8%
# Percent completed:  70.0%
# Percent completed:  70.19999999999999%
# Percent completed:  70.39999999999999%
# Percent completed:  70.6%
# Percent completed:  70.8%
# Percent completed:  71.0%
# Percent completed:  71.2%
# Percent completed:  71.39999999999999%
# Percent completed:  71.6%
# Percent completed:  71.8%
# Percent completed:  72.0%
# Percent completed:  72.2%
# Percent completed:  72.39999999999999%
# Percent completed:  72.6%
# Percent completed:  72.8%
# Percent completed:  73.0%
# Percent completed:  73.2%
# Percent completed:  73.4%
# Percent completed:  73.6%
# Percent completed:  73.8%
# Percent completed:  74.0%
# Percent completed:  74.2%
# Percent completed:  74.4%
# Percent completed:  74.6%
# Percent completed:  74.8%
# Percent completed:  75.0%
# Percent completed:  75.2%
# Percent completed:  75.4%
# Percent completed:  75.6%
# Percent completed:  75.8%
# Percent completed:  76.0%
# Percent completed:  76.2%
# Percent completed:  76.4%
# Percent completed:  76.6%
# Percent completed:  76.8%
# Percent completed:  77.0%
# Percent completed:  77.2%
# Percent completed:  77.4%
# Percent completed:  77.60000000000001%
# Percent completed:  77.8%
# Percent completed:  78.0%
# Percent completed:  78.2%
# Percent completed:  78.4%
# Percent completed:  78.60000000000001%
# Percent completed:  78.8%
# Percent completed:  79.0%
# Percent completed:  79.2%
# Percent completed:  79.4%
# Percent completed:  79.60000000000001%
# Percent completed:  79.80000000000001%
# Percent completed:  80.0%
# Percent completed:  80.2%
# Percent completed:  80.4%
# Percent completed:  80.60000000000001%
# Percent completed:  80.80000000000001%
# Percent completed:  81.0%
# Percent completed:  81.2%
# Percent completed:  81.39999999999999%
# Percent completed:  81.6%
# Percent completed:  81.8%
# Percent completed:  82.0%
# Percent completed:  82.19999999999999%
# Percent completed:  82.39999999999999%
# Percent completed:  82.6%
# Percent completed:  82.8%
# Percent completed:  83.0%
# Percent completed:  83.2%
# Percent completed:  83.39999999999999%
# Percent completed:  83.6%
# Percent completed:  83.8%
# Percent completed:  84.0%
# Percent completed:  84.2%
# Percent completed:  84.39999999999999%
# Percent completed:  84.6%
# Percent completed:  84.8%
# Percent completed:  85.0%
# Percent completed:  85.2%
# Percent completed:  85.39999999999999%
# Percent completed:  85.6%
# Percent completed:  85.8%
# Percent completed:  86.0%
# Percent completed:  86.2%
# Percent completed:  86.4%
# Percent completed:  86.6%
# Percent completed:  86.8%
# Percent completed:  87.0%
# Percent completed:  87.2%
# Percent completed:  87.4%
# Percent completed:  87.6%
# Percent completed:  87.8%
# Percent completed:  88.0%
# Percent completed:  88.2%
# Percent completed:  88.4%
# Percent completed:  88.6%
# Percent completed:  88.8%
# Percent completed:  89.0%
# Percent completed:  89.2%
# Percent completed:  89.4%
# Percent completed:  89.60000000000001%
# Percent completed:  89.8%
# Percent completed:  90.0%
# Percent completed:  90.2%
# Percent completed:  90.4%
# Percent completed:  90.60000000000001%
# Percent completed:  90.8%
# Percent completed:  91.0%
# Percent completed:  91.2%
# Percent completed:  91.4%
# Percent completed:  91.60000000000001%
# Percent completed:  91.8%
# Percent completed:  92.0%
# Percent completed:  92.2%
# Percent completed:  92.4%
# Percent completed:  92.60000000000001%
# Percent completed:  92.80000000000001%
# Percent completed:  93.0%
# Percent completed:  93.2%
# Percent completed:  93.4%
# Percent completed:  93.60000000000001%
# Percent completed:  93.8%
# Percent completed:  94.0%
# Percent completed:  94.19999999999999%
# Percent completed:  94.39999999999999%
# Percent completed:  94.6%
# Percent completed:  94.8%
# Percent completed:  95.0%
# Percent completed:  95.19999999999999%
# Percent completed:  95.39999999999999%
# Percent completed:  95.6%
# Percent completed:  95.8%
# Percent completed:  96.0%
# Percent completed:  96.2%
# Percent completed:  96.39999999999999%
# Percent completed:  96.6%
# Percent completed:  96.8%
# Percent completed:  97.0%
# Percent completed:  97.2%
# Percent completed:  97.39999999999999%
# Percent completed:  97.6%
# Percent completed:  97.8%
# Percent completed:  98.0%
# Percent completed:  98.2%
# Percent completed:  98.4%
# Percent completed:  98.6%
# Percent completed:  98.8%
# Percent completed:  99.0%
# Percent completed:  99.2%
# Percent completed:  99.4%
# Percent completed:  99.6%
# Percent completed:  99.8%
# Percent completed:  100.0%

# %%
cust_slice.grand_errorFrame
# Out:
#   regression approach RMSQE      AE     MAE
# 0    predicted_kwh_rf     0  280388  182.49

# %%
cust_slice_2 = cust_slice.copy()

# %%
my_algorithms_table['algorithm'] = [linear_model.LinearRegression(fit_intercept=True)]

# %%
my_train_columns = ['tavg_intervalSum', 'prev_pd_kwh', 'prev_prev_pd_kwh', 'days_passed', 'iethicalid', 'avg_kwh']
my_categorical_columns = ['month']
my_interaction_columns = [('month', 'tavg_intervalSum', 'categorical', 'numerical')]
cust_slice_2.run_aggregate_models(my_train_columns, my_categorical_columns, my_interaction_columns, 'kwh', my_algorithms_table)

# %%
my_train_columns = ['tavg_intervalSum', 'prev_pd_kwh', 'prev_prev_pd_kwh', 'days_passed']
my_categorical_columns = ['month']

# %%
cust_slice_2.runModels(my_train_columns, my_categorical_columns, 'kwh', my_algorithms_table)
# Out:
# Percent completed:  0.2%
# Percent completed:  0.4%
# Percent completed:  0.6%
# Percent completed:  0.8%
# Percent completed:  1.0%
# Percent completed:  1.2%
# Percent completed:  1.4000000000000001%
# Percent completed:  1.6%
# Percent completed:  1.7999999999999998%
# Percent completed:  2.0%
# Percent completed:  2.1999999999999997%
# Percent completed:  2.4%
# Percent completed:  2.6%
# Percent completed:  2.8000000000000003%
# Percent completed:  3.0%
# Percent completed:  3.2%
# Percent completed:  3.4000000000000004%
# Percent completed:  3.5999999999999996%
# Percent completed:  3.8%
# Percent completed:  4.0%
# Percent completed:  4.2%
# Percent completed:  4.3999999999999995%
# Percent completed:  4.6%
# Percent completed:  4.8%
# Percent completed:  5.0%
# Percent completed:  5.2%
# Percent completed:  5.4%
# Percent completed:  5.6000000000000005%
# Percent completed:  5.800000000000001%
# Percent completed:  6.0%
# Percent completed:  6.2%
# Percent completed:  6.4%
# Percent completed:  6.6000000000000005%
# Percent completed:  6.800000000000001%
# Percent completed:  7.000000000000001%
# Percent completed:  7.199999999999999%
# Percent completed:  7.3999999999999995%
# Percent completed:  7.6%
# Percent completed:  7.8%
# Percent completed:  8.0%
# Percent completed:  8.200000000000001%
# Percent completed:  8.4%
# Percent completed:  8.6%
# Percent completed:  8.799999999999999%
# Percent completed:  9.0%
# Percent completed:  9.2%
# Percent completed:  9.4%
# Percent completed:  9.6%
# Percent completed:  9.8%
# Percent completed:  10.0%
# Percent completed:  10.2%
# Percent completed:  10.4%
# Percent completed:  10.6%
# Percent completed:  10.8%
# Percent completed:  11.0%
# Percent completed:  11.200000000000001%
# Percent completed:  11.4%
# Percent completed:  11.600000000000001%
# Percent completed:  11.799999999999999%
# Percent completed:  12.0%
# Percent completed:  12.2%
# Percent completed:  12.4%
# Percent completed:  12.6%
# Percent completed:  12.8%
# Percent completed:  13.0%
# Percent completed:  13.200000000000001%
# Percent completed:  13.4%
# Percent completed:  13.600000000000001%
# Percent completed:  13.8%
# Percent completed:  14.000000000000002%
# Percent completed:  14.2%
# Percent completed:  14.399999999999999%
# Percent completed:  14.6%
# Percent completed:  14.799999999999999%
# Percent completed:  15.0%
# Percent completed:  15.2%
# Percent completed:  15.4%
# Percent completed:  15.6%
# Percent completed:  15.8%
# Percent completed:  16.0%
# Percent completed:  16.2%
# Percent completed:  16.400000000000002%
# Percent completed:  16.6%
# Percent completed:  16.8%
# Percent completed:  17.0%
# Percent completed:  17.2%
# Percent completed:  17.4%
# Percent completed:  17.599999999999998%
# Percent completed:  17.8%
# Percent completed:  18.0%
# Percent completed:  18.2%
# Percent completed:  18.4%
# Percent completed:  18.6%
# Percent completed:  18.8%
# Percent completed:  19.0%
# Percent completed:  19.2%
# Percent completed:  19.400000000000002%
# Percent completed:  19.6%
# Percent completed:  19.8%
# Percent completed:  20.0%
# Percent completed:  20.200000000000003%
# Percent completed:  20.4%
# Percent completed:  20.599999999999998%
# Percent completed:  20.8%
# Percent completed:  21.0%
# Percent completed:  21.2%
# Percent completed:  21.4%
# Percent completed:  21.6%
# Percent completed:  21.8%
# Percent completed:  22.0%
# Percent completed:  22.2%
# Percent completed:  22.400000000000002%
# Percent completed:  22.6%
# Percent completed:  22.8%
# Percent completed:  23.0%
# Percent completed:  23.200000000000003%
# Percent completed:  23.400000000000002%
# Percent completed:  23.599999999999998%
# Percent completed:  23.799999999999997%
# Percent completed:  24.0%
# Percent completed:  24.2%
# Percent completed:  24.4%
# Percent completed:  24.6%
# Percent completed:  24.8%
# Percent completed:  25.0%
# Percent completed:  25.2%
# Percent completed:  25.4%
# Percent completed:  25.6%
# Percent completed:  25.8%
# Percent completed:  26.0%
# Percent completed:  26.200000000000003%
# Percent completed:  26.400000000000002%
# Percent completed:  26.6%
# Percent completed:  26.8%
# Percent completed:  27.0%
# Percent completed:  27.200000000000003%
# Percent completed:  27.400000000000002%
# Percent completed:  27.6%
# Percent completed:  27.800000000000004%
# Percent completed:  28.000000000000004%
# Percent completed:  28.199999999999996%
# Percent completed:  28.4%
# Percent completed:  28.599999999999998%
# Percent completed:  28.799999999999997%
# Percent completed:  28.999999999999996%
# Percent completed:  29.2%
# Percent completed:  29.4%
# Percent completed:  29.599999999999998%
# Percent completed:  29.799999999999997%
# Percent completed:  30.0%
# Percent completed:  30.2%
# Percent completed:  30.4%
# Percent completed:  30.599999999999998%
# Percent completed:  30.8%
# Percent completed:  31.0%
# Percent completed:  31.2%
# Percent completed:  31.4%
# Percent completed:  31.6%
# Percent completed:  31.8%
# Percent completed:  32.0%
# Percent completed:  32.2%
# Percent completed:  32.4%
# Percent completed:  32.6%
# Percent completed:  32.800000000000004%
# Percent completed:  33.0%
# Percent completed:  33.2%
# Percent completed:  33.4%
# Percent completed:  33.6%
# Percent completed:  33.800000000000004%
# Percent completed:  34.0%
# Percent completed:  34.2%
# Percent completed:  34.4%
# Percent completed:  34.599999999999994%
# Percent completed:  34.8%
# Percent completed:  35.0%
# Percent completed:  35.199999999999996%
# Percent completed:  35.4%
# Percent completed:  35.6%
# Percent completed:  35.8%
# Percent completed:  36.0%
# Percent completed:  36.199999999999996%
# Percent completed:  36.4%
# Percent completed:  36.6%
# Percent completed:  36.8%
# Percent completed:  37.0%
# Percent completed:  37.2%
# Percent completed:  37.4%
# Percent completed:  37.6%
# Percent completed:  37.8%
# Percent completed:  38.0%
# Percent completed:  38.2%
# Percent completed:  38.4%
# Percent completed:  38.6%
# Percent completed:  38.800000000000004%
# Percent completed:  39.0%
# Percent completed:  39.2%
# Percent completed:  39.4%
# Percent completed:  39.6%
# Percent completed:  39.800000000000004%
# Percent completed:  40.0%
# Percent completed:  40.2%
# Percent completed:  40.400000000000006%
# Percent completed:  40.6%
# Percent completed:  40.8%
# Percent completed:  41.0%
# Percent completed:  41.199999999999996%
# Percent completed:  41.4%
# Percent completed:  41.6%
# Percent completed:  41.8%
# Percent completed:  42.0%
# Percent completed:  42.199999999999996%
# Percent completed:  42.4%
# Percent completed:  42.6%
# Percent completed:  42.8%
# Percent completed:  43.0%
# Percent completed:  43.2%
# Percent completed:  43.4%
# Percent completed:  43.6%
# Percent completed:  43.8%
# Percent completed:  44.0%
# Percent completed:  44.2%
# Percent completed:  44.4%
# Percent completed:  44.6%
# Percent completed:  44.800000000000004%
# Percent completed:  45.0%
# Percent completed:  45.2%
# Percent completed:  45.4%
# Percent completed:  45.6%
# Percent completed:  45.800000000000004%
# Percent completed:  46.0%
# Percent completed:  46.2%
# Percent completed:  46.400000000000006%
# Percent completed:  46.6%
# Percent completed:  46.800000000000004%
# Percent completed:  47.0%
# Percent completed:  47.199999999999996%
# Percent completed:  47.4%
# Percent completed:  47.599999999999994%
# Percent completed:  47.8%
# Percent completed:  48.0%
# Percent completed:  48.199999999999996%
# Percent completed:  48.4%
# Percent completed:  48.6%
# Percent completed:  48.8%
# Percent completed:  49.0%
# Percent completed:  49.2%
# Percent completed:  49.4%
# Percent completed:  49.6%
# Percent completed:  49.8%
# Percent completed:  50.0%
# Percent completed:  50.2%
# Percent completed:  50.4%
# Percent completed:  50.6%
# Percent completed:  50.8%
# Percent completed:  51.0%
# Percent completed:  51.2%
# Percent completed:  51.4%
# Percent completed:  51.6%
# Percent completed:  51.800000000000004%
# Percent completed:  52.0%
# Percent completed:  52.2%
# Percent completed:  52.400000000000006%
# Percent completed:  52.6%
# Percent completed:  52.800000000000004%
# Percent completed:  53.0%
# Percent completed:  53.2%
# Percent completed:  53.400000000000006%
# Percent completed:  53.6%
# Percent completed:  53.800000000000004%
# Percent completed:  54.0%
# Percent completed:  54.2%
# Percent completed:  54.400000000000006%
# Percent completed:  54.6%
# Percent completed:  54.800000000000004%
# Percent completed:  55.00000000000001%
# Percent completed:  55.2%
# Percent completed:  55.400000000000006%
# Percent completed:  55.60000000000001%
# Percent completed:  55.800000000000004%
# Percent completed:  56.00000000000001%
# Percent completed:  56.2%
# Percent completed:  56.39999999999999%
# Percent completed:  56.599999999999994%
# Percent completed:  56.8%
# Percent completed:  56.99999999999999%
# Percent completed:  57.199999999999996%
# Percent completed:  57.4%
# Percent completed:  57.599999999999994%
# Percent completed:  57.8%
# Percent completed:  57.99999999999999%
# Percent completed:  58.199999999999996%
# Percent completed:  58.4%
# Percent completed:  58.599999999999994%
# Percent completed:  58.8%
# Percent completed:  59.0%
# Percent completed:  59.199999999999996%
# Percent completed:  59.4%
# Percent completed:  59.599999999999994%
# Percent completed:  59.8%
# Percent completed:  60.0%
# Percent completed:  60.199999999999996%
# Percent completed:  60.4%
# Percent completed:  60.6%
# Percent completed:  60.8%
# Percent completed:  61.0%
# Percent completed:  61.199999999999996%
# Percent completed:  61.4%
# Percent completed:  61.6%
# Percent completed:  61.8%
# Percent completed:  62.0%
# Percent completed:  62.2%
# Percent completed:  62.4%
# Percent completed:  62.6%
# Percent completed:  62.8%
# Percent completed:  63.0%
# Percent completed:  63.2%
# Percent completed:  63.4%
# Percent completed:  63.6%
# Percent completed:  63.800000000000004%
# Percent completed:  64.0%
# Percent completed:  64.2%
# Percent completed:  64.4%
# Percent completed:  64.60000000000001%
# Percent completed:  64.8%
# Percent completed:  65.0%
# Percent completed:  65.2%
# Percent completed:  65.4%
# Percent completed:  65.60000000000001%
# Percent completed:  65.8%
# Percent completed:  66.0%
# Percent completed:  66.2%
# Percent completed:  66.4%
# Percent completed:  66.60000000000001%
# Percent completed:  66.8%
# Percent completed:  67.0%
# Percent completed:  67.2%
# Percent completed:  67.4%
# Percent completed:  67.60000000000001%
# Percent completed:  67.80000000000001%
# Percent completed:  68.0%
# Percent completed:  68.2%
# Percent completed:  68.4%
# Percent completed:  68.60000000000001%
# Percent completed:  68.8%
# Percent completed:  69.0%
# Percent completed:  69.19999999999999%
# Percent completed:  69.39999999999999%
# Percent completed:  69.6%
# Percent completed:  69.8%
# Percent completed:  70.0%
# Percent completed:  70.19999999999999%
# Percent completed:  70.39999999999999%
# Percent completed:  70.6%
# Percent completed:  70.8%
# Percent completed:  71.0%
# Percent completed:  71.2%
# Percent completed:  71.39999999999999%
# Percent completed:  71.6%
# Percent completed:  71.8%
# Percent completed:  72.0%
# Percent completed:  72.2%
# Percent completed:  72.39999999999999%
# Percent completed:  72.6%
# Percent completed:  72.8%
# Percent completed:  73.0%
# Percent completed:  73.2%
# Percent completed:  73.4%
# Percent completed:  73.6%
# Percent completed:  73.8%
# Percent completed:  74.0%
# Percent completed:  74.2%
# Percent completed:  74.4%
# Percent completed:  74.6%
# Percent completed:  74.8%
# Percent completed:  75.0%
# Percent completed:  75.2%
# Percent completed:  75.4%
# Percent completed:  75.6%
# Percent completed:  75.8%
# Percent completed:  76.0%
# Percent completed:  76.2%
# Percent completed:  76.4%
# Percent completed:  76.6%
# Percent completed:  76.8%
# Percent completed:  77.0%
# Percent completed:  77.2%
# Percent completed:  77.4%
# Percent completed:  77.60000000000001%
# Percent completed:  77.8%
# Percent completed:  78.0%
# Percent completed:  78.2%
# Percent completed:  78.4%
# Percent completed:  78.60000000000001%
# Percent completed:  78.8%
# Percent completed:  79.0%
# Percent completed:  79.2%
# Percent completed:  79.4%
# Percent completed:  79.60000000000001%
# Percent completed:  79.80000000000001%
# Percent completed:  80.0%
# Percent completed:  80.2%
# Percent completed:  80.4%
# Percent completed:  80.60000000000001%
# Percent completed:  80.80000000000001%
# Percent completed:  81.0%
# Percent completed:  81.2%
# Percent completed:  81.39999999999999%
# Percent completed:  81.6%
# Percent completed:  81.8%
# Percent completed:  82.0%
# Percent completed:  82.19999999999999%
# Percent completed:  82.39999999999999%
# Percent completed:  82.6%
# Percent completed:  82.8%
# Percent completed:  83.0%
# Percent completed:  83.2%
# Percent completed:  83.39999999999999%
# Percent completed:  83.6%
# Percent completed:  83.8%
# Percent completed:  84.0%
# Percent completed:  84.2%
# Percent completed:  84.39999999999999%
# Percent completed:  84.6%
# Percent completed:  84.8%
# Percent completed:  85.0%
# Percent completed:  85.2%
# Percent completed:  85.39999999999999%
# Percent completed:  85.6%
# Percent completed:  85.8%
# Percent completed:  86.0%
# Percent completed:  86.2%
# Percent completed:  86.4%
# Percent completed:  86.6%
# Percent completed:  86.8%
# Percent completed:  87.0%
# Percent completed:  87.2%
# Percent completed:  87.4%
# Percent completed:  87.6%
# Percent completed:  87.8%
# Percent completed:  88.0%
# Percent completed:  88.2%
# Percent completed:  88.4%
# Percent completed:  88.6%
# Percent completed:  88.8%
# Percent completed:  89.0%
# Percent completed:  89.2%
# Percent completed:  89.4%
# Percent completed:  89.60000000000001%
# Percent completed:  89.8%
# Percent completed:  90.0%
# Percent completed:  90.2%
# Percent completed:  90.4%
# Percent completed:  90.60000000000001%
# Percent completed:  90.8%
# Percent completed:  91.0%
# Percent completed:  91.2%
# Percent completed:  91.4%
# Percent completed:  91.60000000000001%
# Percent completed:  91.8%
# Percent completed:  92.0%
# Percent completed:  92.2%
# Percent completed:  92.4%
# Percent completed:  92.60000000000001%
# Percent completed:  92.80000000000001%
# Percent completed:  93.0%
# Percent completed:  93.2%
# Percent completed:  93.4%
# Percent completed:  93.60000000000001%
# Percent completed:  93.8%
# Percent completed:  94.0%
# Percent completed:  94.19999999999999%
# Percent completed:  94.39999999999999%
# Percent completed:  94.6%
# Percent completed:  94.8%
# Percent completed:  95.0%
# Percent completed:  95.19999999999999%
# Percent completed:  95.39999999999999%
# Percent completed:  95.6%
# Percent completed:  95.8%
# Percent completed:  96.0%
# Percent completed:  96.2%
# Percent completed:  96.39999999999999%
# Percent completed:  96.6%
# Percent completed:  96.8%
# Percent completed:  97.0%
# Percent completed:  97.2%
# Percent completed:  97.39999999999999%
# Percent completed:  97.6%
# Percent completed:  97.8%
# Percent completed:  98.0%
# Percent completed:  98.2%
# Percent completed:  98.4%
# Percent completed:  98.6%
# Percent completed:  98.8%
# Percent completed:  99.0%
# Percent completed:  99.2%
# Percent completed:  99.4%
# Percent completed:  99.6%
# Percent completed:  99.8%
# Percent completed:  100.0%

# %%
cust_slice_2.agg_errorFrame
# Out:
#   regression approach RMSQE     AE      MAE
# 0    predicted_kwh_rf     0  99911  199.822

# %%
cust_slice_2.grand_errorFrame
# Out:
#   regression approach RMSQE      AE      MAE
# 0    predicted_kwh_rf     0  597887  435.146

# %%
(my_algorithms_table['fitted_model'][0].coef_)
# Out:
# array([[  7.06375780e-02,   6.40548863e-01,  -1.91718810e-01,
#           1.02213029e-03,  -2.20855830e-05,   5.53862331e-01,
#           2.59409926e+02,   4.22033369e+02,   2.10022154e+02,
#           1.16762372e+02,  -1.82892428e+02,  -3.68279241e+02,
#          -2.32242867e+02,  -2.75954007e+01,  -1.56600097e+02,
#          -6.01351608e+02,   4.10225969e+02,   1.50507852e+02,
#          -6.37806867e-02,  -3.03931205e-01,  -9.37582428e-02,
#          -9.26762162e-02,   7.98185044e-02,   2.05950737e-01,
#           1.61117594e-01,   5.58953586e-02,   8.20330698e-02,
#           2.65880299e-01,  -2.23586438e-01,  -2.32519222e-03]])

# %%
cust_slice.aggFrame['kwh'].sum()/len(cust_slice.aggFrame)
# Out:
# 642.8814000601593
